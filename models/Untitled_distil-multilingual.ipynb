# %%
import os
os.chdir('/Users/nico/Desktop/Github')
print(os.getcwd())
# Out:
# /Users/nico/Desktop/Github

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import numpy as np

# %%
df = pd.read_csv('sarcasm_detection/data/corpora_dataset.csv', sep=';')
df.head()
# Out:
#                                               titles category  Label
# 0  Trentino, femministe chiedono l'abbattimento d...  cronaca      1
# 1  "Voglio essere come lui!" Bambino guarda video...  cronaca      1
# 2  "Vorrei staccare la spina". Sospeso medico ria...  cronaca      1
# 3  Gatta muore al pronto soccorso per animali, ve...  cronaca      1
# 4  Bologna, Comune installa sui semafori piccioni...  cronaca      1

# %%
label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
n_positive = df[df['Label'] == 1].shape[0]  # Number of sarcastic examples
n_negative = df[df['Label'] == 0].shape[0]  # Number of non-sarcastic examples

rows_to_remove = n_negative - n_positive

if pd.api.types.is_numeric_dtype(df.index):  # If index is numeric
    rows_to_delete = np.random.choice(df[df['Label'] == 0].index, rows_to_remove, replace=False)
else:  # If index is not numeric (e.g., strings)
    rows_to_delete = list(df[df['Label'] == 0].sample(rows_to_remove, replace=False).index)

df = df.drop(rows_to_delete)


label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/nico/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

df = df[df['titles'].str.len() >= 20] # remove short titles

df['titles'] = df['titles'].str.lower() # lowercasing

df['titles'] = df['titles'].str.replace('[^\w\s]', '', regex=True) # removing punctuation

#df['titles'] = df['titles'].str.replace('\d+', '', regex=True) # removing numbers?

# Removing stop words
stop = set(stopwords.words('italian'))
df['titles'] = df['titles'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop]))

# lemmatization
lemmatizer = WordNetLemmatizer()
df['titles'] = df['titles'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# remove extra whitespace
df['titles'] = df['titles'].str.strip()
df['titles'] = df['titles'].str.replace('\s+', ' ', regex=True)

df.head()
# Out:
#                                               titles category  Label
# 0  trentino femministe chiedono labbattimento del...  cronaca      1
# 1  voglio essere bambino guarda video salvini dec...  cronaca      1
# 2  vorrei staccare spina sospeso medico rianimato...  cronaca      1
# 3  gatta muore pronto soccorso animali veterinari...  cronaca      1
# 4  bologna comune installa semafori piccioni adde...  cronaca      1

# %%
from sklearn.model_selection import train_test_split

train_texts, temp_texts, train_labels, temp_labels = train_test_split(df['titles'], df['Label'], test_size=0.2, random_state=42)

val_texts, test_texts, val_labels, test_labels = train_test_split(temp_texts, temp_labels, test_size=0.5, random_state=42)

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = 'distilbert/distilbert-base-multilingual-cased'

# tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Tokenize the texts
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True)

val_encodings = tokenizer(val_texts.tolist(), truncation=True, padding=True)

test_encodings = tokenizer(test_texts.tolist(), truncation=True, padding=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import torch

# define a PyTorch dataset

class SarcasmDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
         self.encodings = encodings
         self.labels = labels
        
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]) 
        return item
        
    def __len__(self):
        return len(self.labels)

# %%
# convert our tokenized data into a torch datasets
train_dataset = SarcasmDataset(train_encodings, train_labels.tolist())
val_dataset = SarcasmDataset(val_encodings, val_labels.tolist())
test_dataset = SarcasmDataset(test_encodings, test_labels.tolist())

# %%
model = AutoModelForSequenceClassification.from_pretrained(model_name)  # num_labels=2 for binary classification
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert/distilbert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer, TrainingArguments, EarlyStoppingCallback

training_args = TrainingArguments(
    output_dir='./outputs',
    num_train_epochs=4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    warmup_steps=100,
    learning_rate=0.0001,
    logging_dir='./logs',
    logging_strategy='steps',
    logging_steps=100,
    evaluation_strategy='steps',
    save_steps=200,
    eval_steps=200,
    load_best_model_at_end=True,
    save_total_limit=2
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2288' max='2288' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2288/2288 18:03, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.466500</td>
#       <td>0.494188</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.368100</td>
#       <td>0.389056</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.323100</td>
#       <td>0.333056</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.220600</td>
#       <td>0.289607</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.208600</td>
#       <td>0.308079</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.137100</td>
#       <td>0.394579</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.082400</td>
#       <td>0.473953</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.076000</td>
#       <td>0.520281</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.030100</td>
#       <td>0.528393</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.020300</td>
#       <td>0.562043</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.023000</td>
#       <td>0.586779</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2288, training_loss=0.18485867331078001, metrics={'train_runtime': 1093.3933, 'train_samples_per_second': 33.481, 'train_steps_per_second': 2.093, 'total_flos': 369385341152256.0, 'train_loss': 0.18485867331078001, 'epoch': 4.0})

# %%
import matplotlib.pyplot as plt

train_stats = trainer.state.log_history

train_loss = [x['loss'] for x in train_stats if 'loss' in x]
eval_loss = [x['eval_loss'] for x in train_stats if 'eval_loss' in x]

train_steps = [x['step'] for x in train_stats if 'loss' in x]
eval_steps = [x['step'] for x in train_stats if 'eval_loss' in x]

plt.figure(figsize=(10, 6))
plt.plot(train_steps, train_loss, label='Training Loss')
plt.plot(eval_steps, eval_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Losses Over Steps')
plt.show()

# %%
import numpy as np

# Evaluate the model
eval_results = trainer.evaluate(test_dataset)

# Print evaluation results
print(eval_results)

# Predict on new data
predictions = trainer.predict(test_dataset)

# The predictions are in logits. Convert them to class labels.
predicted_labels = np.argmax(predictions.predictions, axis=1)

print(predicted_labels)
# Out:
# {'eval_loss': 0.3250415623188019, 'eval_runtime': 4.8766, 'eval_samples_per_second': 234.793, 'eval_steps_per_second': 7.382, 'epoch': 4.0}
# [1 1 1 ... 0 1 1]

# %%
df_pred = pd.DataFrame({
    'titles': test_texts,
    'Label': test_labels
})

df_pred['predictions'] = predicted_labels

df_pred.head()
# Out:
#                                                  titles  Label  predictions
# 4092  terra fuochi campania celebra eccellenze inaug...      1            1
# 1701  salvini sbaglia redigere comunicato estende li...      1            1
# 2036  meeting fdi giorgia meloni prende distanze fas...      1            1
# 9994  truppe nato ucraina no macron fuga avanti lita...      0            0
# 730   crollo viadotto torinosavona protezione civile...      1            1

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def evaluate_predictions(df):
    errors = df[df['Label'] != df['predictions']]
    num_errors = len(errors)
    
    print(f"\nNumber of errors: {num_errors}\n")
    
    accuracy = accuracy_score(df['Label'], df['predictions'])
    f1 = f1_score(df['Label'], df['predictions'])
    precision = precision_score(df['Label'], df['predictions'])
    recall = recall_score(df['Label'], df['predictions'])

    print(f"Accuracy: {accuracy}")
    print(f"F1 Score: {f1}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}\n")

    print("Misclassified titles:\n")
    for index, row in errors.iterrows():
        label = "sarcastic" if row['Label'] == 1 else "not sarcastic"
        prediction = "sarcastic" if row['predictions'] == 1 else "not sarcastic"
        print(f"Title: {row['titles']}, Label: {label}, Prediction: {prediction}")

# %%
evaluate_predictions(df_pred)
# Out:
# Number of errors: 157
#
# Accuracy: 0.862882096069869
# F1 Score: 0.86615515771526
# Precision: 0.8743545611015491
# Recall: 0.8581081081081081
#
# Misclassified titles:
#
# Title: nobel fisica 2020 penrose genzel ghez scoperte buchi neri, Label: not sarcastic, Prediction: sarcastic
# Title: spende 500 euro cosplay aggiudica premio miglior cosplay 100 euro, Label: sarcastic, Prediction: not sarcastic
# Title: larticolo telegraph disinforma sullorigine sarscov2, Label: not sarcastic, Prediction: sarcastic
# Title: morte costanzo settimanale rivela massimo lopez leggerà testamento imitando voce, Label: sarcastic, Prediction: not sarcastic
# Title: lol 5 rischio lannuncio prime finiti jackal far partecipare, Label: sarcastic, Prediction: not sarcastic
# Title: guerra ucraina putin mercoledì pechino incontrare presidente cinese xi jinping, Label: not sarcastic, Prediction: sarcastic
# Title: cinema problemi prossimo film 007 bond vuole essere servizio segreto carlo, Label: sarcastic, Prediction: not sarcastic
# Title: milanese regala sveglia cugino napoletano procura infarto, Label: sarcastic, Prediction: not sarcastic
# Title: segreto scacchi grande enigma vince intelligente esperto, Label: not sarcastic, Prediction: sarcastic
# Title: grammatica inutile fare illudere nuove generazioni eliminato insegnamento tempo futuro, Label: sarcastic, Prediction: not sarcastic
# Title: economia cosa annuncia 5000 posti lavoro entro fine dellanno, Label: sarcastic, Prediction: not sarcastic
# Title: revisionismo meloni continuum falcone ucciso siciliano, Label: sarcastic, Prediction: not sarcastic
# Title: servizi segreti vanno tilt ricompare marina ovsyannikova scompare nuovo tennista cinese, Label: sarcastic, Prediction: not sarcastic
# Title: nave aquarius salva cucciolo delfino salvini ordina limmediata riapertura porti, Label: sarcastic, Prediction: not sarcastic
# Title: rom licenziata lestetista ansiosa manicure denti, Label: sarcastic, Prediction: not sarcastic
# Title: rom dentista scambia tumore gengivite, Label: not sarcastic, Prediction: sarcastic
# Title: psichiatra crepet trap ascolta diventa drogato reazione frankie hinrg, Label: not sarcastic, Prediction: sarcastic
# Title: membri gen z inclini baby boomer pensare femminismo problema, Label: not sarcastic, Prediction: sarcastic
# Title: ombre dietro turismo dentale albania lallarme medici italiani tocca rimediare, Label: not sarcastic, Prediction: sarcastic
# Title: usa premier meloni incontra henry kissinger menti lucide, Label: not sarcastic, Prediction: sarcastic
# Title: dietologo fa dimagrire nutella pasta pizza perdere peso può essere tortura, Label: not sarcastic, Prediction: sarcastic
# Title: simona ventura viso bloccato paralisi facciale bocca storta lipotesi freddo, Label: not sarcastic, Prediction: sarcastic
# Title: ancora guai barbie rischio censura libano promuove lomosessualità, Label: not sarcastic, Prediction: sarcastic
# Title: premio oscar nuova beffa barbie ryan gosling nominato miglior attrice, Label: sarcastic, Prediction: not sarcastic
# Title: clamorosa sconfitta napoli marisa laurito va bene va bene spoglio, Label: sarcastic, Prediction: not sarcastic
# Title: como prof cerca separare due alunni 13 anni durante lite picchiato finisce ospedale, Label: not sarcastic, Prediction: sarcastic
# Title: mancata benedizione cane unità cinofila vendica scovando prove vaticano caso orlandi, Label: sarcastic, Prediction: not sarcastic
# Title: fondi russi partiti potere popolo smarca visto vestiamo, Label: sarcastic, Prediction: not sarcastic
# Title: fedez ferragni furiosa rosa chemical fatto pure regalo san valentino, Label: sarcastic, Prediction: not sarcastic
# Title: sothebys inedita foto dargen damico senza occhiali battuta allasta 3 centesimo, Label: sarcastic, Prediction: not sarcastic
# Title: festival sanremo kamikaze fa esplodere allariston vince premio critica, Label: sarcastic, Prediction: not sarcastic
# Title: cartello shock ristorante davos affittiamo slittini ebrei protesta comunità ebraica, Label: not sarcastic, Prediction: sarcastic
# Title: siccità prosciuga fiumi aar inn isar chiudono tutte riviste enigmistica, Label: sarcastic, Prediction: not sarcastic
# Title: colomba pace lancia pasti fast food nuova opera harrygreb rom, Label: not sarcastic, Prediction: sarcastic
# Title: rai 1 imbarazzo momento ghigliottina parola serata nana merda, Label: sarcastic, Prediction: not sarcastic
# Title: festival sanremo nuovo regolamento cantanti eliminati strappata lingua, Label: sarcastic, Prediction: not sarcastic
# Title: scuola bagni senza carta bambino costretto pulirsi foto presidente denunciato vilipendio, Label: sarcastic, Prediction: not sarcastic
# Title: studio shock cambiamento climatico nebbia tutta lestate sud, Label: sarcastic, Prediction: not sarcastic
# Title: michelle obama intende correre presidenza usa, Label: not sarcastic, Prediction: sarcastic
# Title: viva rai 2 nuova bega fiorello dehor trasmettendo abusivo, Label: not sarcastic, Prediction: sarcastic
# Title: esistono mancini misteri falsi miti usa mano sinistra così pochi, Label: not sarcastic, Prediction: sarcastic
# Title: porta porta bruno vespa mangia piatto spaghetti forchettone funivia mottarone, Label: sarcastic, Prediction: not sarcastic
# Title: appetibili quindi pericolose usa vogliono mettere bando sigarette mentolo, Label: not sarcastic, Prediction: sarcastic
# Title: napoli via circolazione targhe alterne giorno vere giorno false, Label: sarcastic, Prediction: not sarcastic
# Title: test antigenico fa scoprire tumori venti minuti quasi, Label: not sarcastic, Prediction: sarcastic
# Title: prevedere avverranno eruzioni sfida vulcanologi laiuto statistica, Label: not sarcastic, Prediction: sarcastic
# Title: neofascisti schierano negazionisti virus fatto cose buone, Label: sarcastic, Prediction: not sarcastic
# Title: susanna tamaro ecco parodie libri daniele luttazzi, Label: sarcastic, Prediction: not sarcastic
# Title: giorgia meloni prende distanze destra estrema mussolini fatto cose buonine, Label: sarcastic, Prediction: not sarcastic
# Title: lesa addestrando astronauti tornare luna, Label: not sarcastic, Prediction: sarcastic
# Title: randi ingerman soffre epilessia depressione primo passo uscirne chiedere aiuto, Label: not sarcastic, Prediction: sarcastic
# Title: eutanasia legale potrà urlare pizza napoletana fa schifo piazza plebiscito napoli, Label: sarcastic, Prediction: not sarcastic
# Title: cernobbio sogno nucleare governo salvini inaugureremo prima centrale pichetto fratin lancia piattaforma hoc, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus nuovo decreto lautocertificazione dovrà essere firmata sangue, Label: sarcastic, Prediction: not sarcastic
# Title: intervista esclusiva morte dovuta andare berlusconi cambiato idea, Label: sarcastic, Prediction: not sarcastic
# Title: chiara ferragni annuncia pausa social instagram solo 23 ore mezza giorno, Label: sarcastic, Prediction: not sarcastic
# Title: primarie cuperlo scatenato luomo giusto far perdere pd, Label: sarcastic, Prediction: not sarcastic
# Title: lartista ascoltato italia nuovo carcere baby gang primo classifica sbarre busto arsizio, Label: not sarcastic, Prediction: sarcastic
# Title: papa francesco sesso dono dio minacciato pornografia, Label: not sarcastic, Prediction: sarcastic
# Title: solo assegno unico commissione europea apre uninfrazione concessioni balneari, Label: not sarcastic, Prediction: sarcastic
# Title: lupi smentisce accuse favoritismo lascia lincarico ministro figlio, Label: sarcastic, Prediction: not sarcastic
# Title: candida auris cosè patogeno resiste terapie, Label: not sarcastic, Prediction: sarcastic
# Title: fatto tanto destra italiana ignazio russa mette busto soumahoro casa, Label: sarcastic, Prediction: not sarcastic
# Title: spazzatura spaziale accumula soluzione satelliti spazzini, Label: not sarcastic, Prediction: sarcastic
# Title: grande fratello vip 50 concorrenti sa motivo famoso, Label: sarcastic, Prediction: not sarcastic
# Title: migranti meloni ammette difficoltà risultati sperati dopo anno governo litalia credibile, Label: not sarcastic, Prediction: sarcastic
# Title: calcio respinto ricorso lazio curva nord rimarrà chiusa cori razzisti, Label: not sarcastic, Prediction: sarcastic
# Title: netanyahu operato dernia compensare israele troverà dieci palestinesi farla venire, Label: sarcastic, Prediction: not sarcastic
# Title: verdi eleonora evi dimette marionetta pinkwashing, Label: not sarcastic, Prediction: sarcastic
# Title: arisa essere amata dimagrita ingrassata qualsiasi cosa, Label: not sarcastic, Prediction: sarcastic
# Title: nord stream 2 rivelazione washington post lucraina far saltare aria gasdotto, Label: not sarcastic, Prediction: sarcastic
# Title: uomo ubriaco morde unassistente volo aereo giapponese diretto usa fa ritorno tokyo, Label: not sarcastic, Prediction: sarcastic
# Title: miracolato wojtyla paralitico guarisce torna fare killer, Label: sarcastic, Prediction: not sarcastic
# Title: disoccupati denunciano dopo job act perseguitati offerte lavoro, Label: sarcastic, Prediction: not sarcastic
# Title: giorgia meloni prende distanze destra estrema mussolini fatto cose buonine, Label: sarcastic, Prediction: not sarcastic
# Title: medio oriente tensione momento quasi livello terzo polo, Label: sarcastic, Prediction: not sarcastic
# Title: simone inzaghi rivincita mister superato trofei mou, Label: not sarcastic, Prediction: sarcastic
# Title: fantacalcio mirino dellagenzia entrate giro evasione 2 miliardi euro, Label: sarcastic, Prediction: not sarcastic
# Title: toninelli sì governo draghi patto presidente consiglio conte, Label: sarcastic, Prediction: not sarcastic
# Title: sciopero nazionale supermercati vigilia pasqua, Label: not sarcastic, Prediction: sarcastic
# Title: miley cyrus torna disney world arrestata stupro dinamite bla, Label: sarcastic, Prediction: not sarcastic
# Title: nomi ambigui enel santal sindaco venezia vieta libro gender pagine gialle, Label: sarcastic, Prediction: not sarcastic
# Title: superenalotto parla vincitori credo meritocrazia, Label: sarcastic, Prediction: not sarcastic
# Title: messo amici lavorare ruoli giorgia meloni arriva tiktok primo singolo suspect cb ernia, Label: not sarcastic, Prediction: sarcastic
# Title: todde tentativi precedenti 5 stelle conquistare regione molise allumbria, Label: not sarcastic, Prediction: sarcastic
# Title: fa chiamare macron sibilia giuseppe conte unora telefono signor marcon treviso, Label: sarcastic, Prediction: not sarcastic
# Title: putin respinge dubbi salute mentale nomina ministro esteri cavallo, Label: sarcastic, Prediction: not sarcastic
# Title: johnny depp nuove accuse allex moglie ogni mattina leggeva alta voce caffè gramellini, Label: sarcastic, Prediction: not sarcastic
# Title: dopo taiwan nancy pelosi va toscana scoppia guerra pisa livorno, Label: sarcastic, Prediction: not sarcastic
# Title: netflix scoperto menù segreto può perdere ulteriore tempo scegliere cosa vedere, Label: sarcastic, Prediction: not sarcastic
# Title: laurea 110 lode medicina studiando testi cannibal corpse, Label: sarcastic, Prediction: not sarcastic
# Title: aquarius dietrofront spagna litalia detto bordo bonghisti, Label: sarcastic, Prediction: not sarcastic
# Title: freccero rai2 tele padre pio diretta salma casaleggio h24, Label: sarcastic, Prediction: not sarcastic
# Title: marcello dellutri rinuncia ricorso sequestro 108 milioni, Label: not sarcastic, Prediction: sarcastic
# Title: grecia parlamento legalizza matrimoni adozioni coppie omosessuali, Label: not sarcastic, Prediction: sarcastic
# Title: zangrillo pronto clonare berlusconi frammenti dna recuperati lingua centinaia giornalisti, Label: sarcastic, Prediction: not sarcastic
# Title: alfasigma contest concorso giornalisti futuro, Label: not sarcastic, Prediction: sarcastic
# Title: bloccato dogana tir carico bambino diretto italia adozioni gay, Label: sarcastic, Prediction: not sarcastic
# Title: internazionali rom berrettini annuncia ritiro pronto rischio farmi male, Label: not sarcastic, Prediction: sarcastic
# Title: coldplay vogliono incidere canzone dentro voci fan date mano costruire one world, Label: not sarcastic, Prediction: sarcastic
# Title: luca parmitano foto passeggiata spaziale terra diventa sfondo, Label: not sarcastic, Prediction: sarcastic
# Title: federico fashion style aggredito treno schiaffi pugni gay, Label: not sarcastic, Prediction: sarcastic
# Title: dice imparato musica maestro piano ucciso serial killer sgrammaticati, Label: sarcastic, Prediction: not sarcastic
# Title: matteo renzi piano berlusconi quirinale grazia dellutri, Label: not sarcastic, Prediction: sarcastic
# Title: arriva pizza serpente potrà mangiare ovunque, Label: not sarcastic, Prediction: sarcastic
# Title: caccia tesoro agnelli paradisi fiscali, Label: not sarcastic, Prediction: sarcastic
# Title: prime proteste san marino circondati nato, Label: sarcastic, Prediction: not sarcastic
# Title: salvini contrario linea governo favorevole decisioni prese dallesecutivo, Label: sarcastic, Prediction: not sarcastic
# Title: milanese regala sveglia cugino napoletano procura infarto, Label: sarcastic, Prediction: not sarcastic
# Title: laura matteotti governo ricorda nonno fascisti, Label: not sarcastic, Prediction: sarcastic
# Title: mamma italiana diventa campionessa mondiale lancio ciabatta, Label: sarcastic, Prediction: not sarcastic
# Title: anelli saturno molto giovani pensassimo, Label: not sarcastic, Prediction: sarcastic
# Title: londra fabrizio corona fermato accusato cannibalismo, Label: sarcastic, Prediction: not sarcastic
# Title: stalker travestiva clown terrorizzare ragazza torino, Label: not sarcastic, Prediction: sarcastic
# Title: spalletti nazionale giovani mettono musino ogni banalità poca voglia sacrifici, Label: not sarcastic, Prediction: sarcastic
# Title: salone libro parte canzone fascista faccetta nera mentre parla pd stato hacker, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus studio italiano suggerisce promettenti effetti tocilizumab, Label: not sarcastic, Prediction: sarcastic
# Title: ispiro idolo neymar dedica cr7 accuse stupro, Label: sarcastic, Prediction: not sarcastic
# Title: scoperto asteroide potrebbe aiutarci capire levoluzione pianeti, Label: not sarcastic, Prediction: sarcastic
# Title: angelo duro grazie buonisti vendo biglietti diventato ricco, Label: not sarcastic, Prediction: sarcastic
# Title: family day critiche scelta rom città fondata mamma lupa, Label: sarcastic, Prediction: not sarcastic
# Title: eurovision già arrivati svezia primo 200 tir lustrini paillettes, Label: sarcastic, Prediction: not sarcastic
# Title: rom terminus tassista rifiuta cliente disabile multato 600 euro, Label: not sarcastic, Prediction: sarcastic
# Title: polmoniti cina centrum realmente mycoplasma pneumoniae, Label: not sarcastic, Prediction: sarcastic
# Title: west nile virus cè ragione cadere panico raddoppiano casi italia, Label: not sarcastic, Prediction: sarcastic
# Title: morto vecchiaia toyboy regina elisabetta, Label: sarcastic, Prediction: not sarcastic
# Title: team ricercatori italiani comunicando spazio fotoni, Label: not sarcastic, Prediction: sarcastic
# Title: nicola gratteri conference call mafioso prigione allaltra, Label: not sarcastic, Prediction: sarcastic
# Title: medicina ecco ascoltare achille lauro allevia dolori mestruali, Label: sarcastic, Prediction: not sarcastic
# Title: rom investe pensionato assolto grazie caz codice automobilistico zingaro, Label: sarcastic, Prediction: not sarcastic
# Title: ecco nuova bibbia gender adamo gay eva lesbica caino adottato abele nato provetta, Label: sarcastic, Prediction: not sarcastic
# Title: svaligiavano ville travestiti rom sostenere campagna elettorale salvini arrestati, Label: sarcastic, Prediction: not sarcastic
# Title: robot killer gruppo scienziati chiede vietare armi grado uccidere sole, Label: not sarcastic, Prediction: sarcastic
# Title: basta sete stappa madonna campagna papa francesco sete mondo, Label: sarcastic, Prediction: not sarcastic
# Title: sente solo chiama carabinieri brindisi arrestato matteo messina denaro, Label: sarcastic, Prediction: not sarcastic
# Title: appello salvare huaiheem siei condannato morte nome, Label: sarcastic, Prediction: not sarcastic
# Title: novak djokovic vaccinato può entrare usa salta indian well, Label: not sarcastic, Prediction: sarcastic
# Title: marco travaglio riscrive regole monopoli finisce prigione può uscire, Label: sarcastic, Prediction: not sarcastic
# Title: parla sestini lautore foto ritrae goggia due piedi sinistri spiego nasce lerrore, Label: not sarcastic, Prediction: sarcastic
# Title: ambiente paradossi cina campionessa emissioni prima ogni classifica clima, Label: not sarcastic, Prediction: sarcastic
# Title: vita elon musk diventa film dirigere biopic regista darren aronofsky, Label: not sarcastic, Prediction: sarcastic
# Title: codacons scrive fabio fazio lettera 7 domande fare chiara ferragni, Label: not sarcastic, Prediction: sarcastic
# Title: revenge porn emendamento lega reato pubblicare foto dellex testi gio evan, Label: sarcastic, Prediction: not sarcastic
# Title: sogno inter doppia stella nerazzurri vincono ventesimo scudetto, Label: not sarcastic, Prediction: sarcastic
# Title: chiara ferragni annuncia pausa social instagram solo 23 ore mezza giorno, Label: sarcastic, Prediction: not sarcastic
# Title: vaccini nuovo errore iniettate sbaglio 22enne tre milioni dosi, Label: sarcastic, Prediction: not sarcastic
# Title: ecco cosa succede fate bollire lacqua rubinetto video, Label: sarcastic, Prediction: not sarcastic
# Title: lucio caracciolo spiego perdendo guerra grande ucraina medio oriente, Label: not sarcastic, Prediction: sarcastic
# Title: nuova rai programma divulgazione scientifica condotto bigfoot, Label: sarcastic, Prediction: not sarcastic
# Title: pillola lobesità base semaglutide fa perdere 15 peso, Label: not sarcastic, Prediction: sarcastic
# Title: antivax protagonista rain man stato vaccinato big pharma fatto tagliare scena, Label: sarcastic, Prediction: not sarcastic
# Title: commessa malata cancro licenziata supermercato fa causa vince tribunale, Label: not sarcastic, Prediction: sarcastic
# Title: meloni raddoppia stanziamento aiuti militari allucraina così comici russi imparano, Label: sarcastic, Prediction: not sarcastic
# Title: quando dobbiamo lasciarci fedez lancia sondaggio instagram decidere data divorzio, Label: sarcastic, Prediction: not sarcastic
# Title: chiara ferragni lieto annuncio aspetto nuovo profilo instagram, Label: sarcastic, Prediction: not sarcastic
# Title: nairobi u2 concerto cancellazione dellimu, Label: sarcastic, Prediction: not sarcastic
# Title: vaccini studio confermare mostra lefficacia pfizer 7 mesi booster omicron, Label: not sarcastic, Prediction: sarcastic

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = df_pred['Label']
predicted_labels = df_pred['predictions']

conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

precision, recall, _ = precision_recall_curve(true_labels, predicted_labels)
average_precision = average_precision_score(true_labels, predicted_labels)

# Plot precision-recall curve
plt.figure(figsize=(8, 6))
plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve (AP={0:0.2f})'.format(average_precision))
plt.show()

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(true_labels, predicted_labels, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Calibration Curve', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('Predicted Probability')
plt.ylabel('True Probability')
plt.title('Calibration Curve')
plt.legend(loc='lower right')
plt.show()
