# %%
import os
os.chdir('/Users/nico/Desktop/Github')
print(os.getcwd())
# Out:
# /Users/nico/Desktop/Github

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import numpy as np

# %%
df = pd.read_csv('sarcasm_detection/data/corpora_dataset.csv', sep=';')
df.head()
# Out:
#                                               titles category  Label
# 0  Trentino, femministe chiedono l'abbattimento d...  cronaca      1
# 1  "Voglio essere come lui!" Bambino guarda video...  cronaca      1
# 2  "Vorrei staccare la spina". Sospeso medico ria...  cronaca      1
# 3  Gatta muore al pronto soccorso per animali, ve...  cronaca      1
# 4  Bologna, Comune installa sui semafori piccioni...  cronaca      1

# %%
label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
n_positive = df[df['Label'] == 1].shape[0]  # Number of sarcastic examples
n_negative = df[df['Label'] == 0].shape[0]  # Number of non-sarcastic examples

rows_to_remove = n_negative - n_positive

if pd.api.types.is_numeric_dtype(df.index):  # If index is numeric
    rows_to_delete = np.random.choice(df[df['Label'] == 0].index, rows_to_remove, replace=False)
else:  # If index is not numeric (e.g., strings)
    rows_to_delete = list(df[df['Label'] == 0].sample(rows_to_remove, replace=False).index)

df = df.drop(rows_to_delete)


label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/nico/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

df = df[df['titles'].str.len() >= 20] # remove short titles

df['titles'] = df['titles'].str.lower() # lowercasing

df['titles'] = df['titles'].str.replace('[^\w\s]', '', regex=True) # removing punctuation

# Removing stop words
stop = set(stopwords.words('italian'))
df['titles'] = df['titles'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop]))

# lemmatization
lemmatizer = WordNetLemmatizer()
df['titles'] = df['titles'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# remove extra whitespace
df['titles'] = df['titles'].str.strip()
df['titles'] = df['titles'].str.replace('\s+', ' ', regex=True)

df.head()
# Out:
#                                               titles category  Label
# 0  trentino femministe chiedono labbattimento del...  cronaca      1
# 1  voglio essere bambino guarda video salvini dec...  cronaca      1
# 2  vorrei staccare spina sospeso medico rianimato...  cronaca      1
# 3  gatta muore pronto soccorso animali veterinari...  cronaca      1
# 4  bologna comune installa semafori piccioni adde...  cronaca      1

# %%
from sklearn.model_selection import train_test_split

train_texts, temp_texts, train_labels, temp_labels = train_test_split(df['titles'], df['Label'], test_size=0.2, random_state=42)

val_texts, test_texts, val_labels, test_labels = train_test_split(temp_texts, temp_labels, test_size=0.5, random_state=42)

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification

model_name = 'roberta-base'

# tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)

# Tokenize the texts
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True)

val_encodings = tokenizer(val_texts.tolist(), truncation=True, padding=True)

test_encodings = tokenizer(test_texts.tolist(), truncation=True, padding=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import torch

# define a PyTorch dataset

class SarcasmDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
         self.encodings = encodings
         self.labels = labels
        
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]) 
        return item
        
    def __len__(self):
        return len(self.labels)

# %%
# convert our tokenized data into a torch datasets
train_dataset = SarcasmDataset(train_encodings, train_labels.tolist())
val_dataset = SarcasmDataset(val_encodings, val_labels.tolist())
test_dataset = SarcasmDataset(test_encodings, test_labels.tolist())

# %%
model = RobertaForSequenceClassification.from_pretrained(model_name)  # num_labels=2 for binary classification
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def delete_existing_log_files(logging_dir):
    if os.path.exists(logging_dir):
        for filename in os.listdir(logging_dir):
            file_path = os.path.join(logging_dir, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    os.rmdir(file_path)
            except Exception as e:
                print(f'Failed to delete {file_path}. Reason: {e}')

# %%
from transformers import Trainer, TrainingArguments, EarlyStoppingCallback

training_args = TrainingArguments(
    output_dir='./outputs',
    num_train_epochs=6,
    per_device_train_batch_size=48,
    per_device_eval_batch_size=32,
    warmup_steps=100,
    learning_rate=0.0001,
    logging_dir='./logs',
    logging_strategy='steps',
    logging_steps=100,
    evaluation_strategy='steps',
    save_steps=200,
    eval_steps=200,
    load_best_model_at_end=True,
    save_total_limit=2
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)],
)

# %%
delete_existing_log_files(training_args.logging_dir)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='1146' max='1146' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1146/1146 39:21, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.502200</td>
#       <td>0.520653</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.414700</td>
#       <td>0.435988</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.304900</td>
#       <td>0.367948</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.205800</td>
#       <td>0.334929</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.135700</td>
#       <td>0.408962</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1146, training_loss=0.30655277565927824, metrics={'train_runtime': 2366.2647, 'train_samples_per_second': 23.206, 'train_steps_per_second': 0.484, 'total_flos': 1467370355742720.0, 'train_loss': 0.30655277565927824, 'epoch': 6.0})

# %%
train_stats = trainer.state.log_history

train_loss = [x['loss'] for x in train_stats if 'loss' in x]
eval_loss = [x['eval_loss'] for x in train_stats if 'eval_loss' in x]

train_steps = [x['step'] for x in train_stats if 'loss' in x]
eval_steps = [x['step'] for x in train_stats if 'eval_loss' in x]

plt.figure(figsize=(10, 6))
plt.plot(train_steps, train_loss, label='Training Loss')
plt.plot(eval_steps, eval_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Losses Over Steps')
plt.show()

# %%
# Evaluate the model
eval_results = trainer.evaluate(test_dataset)

# Print evaluation results
print(eval_results)

# Predict on new data
predictions = trainer.predict(test_dataset)

# The predictions are in logits. Convert them to class labels.
predicted_labels = np.argmax(predictions.predictions, axis=1)

print(predicted_labels)
# Out:
# {'eval_loss': 0.39539825916290283, 'eval_runtime': 5.9695, 'eval_samples_per_second': 191.807, 'eval_steps_per_second': 6.031, 'epoch': 6.0}
# [1 1 1 ... 0 1 1]

# %%
df_pred = pd.DataFrame({
    'titles': test_texts,
    'Label': test_labels
})

df_pred['predictions'] = predicted_labels

df_pred.head()
# Out:
#                                                  titles  Label  predictions
# 4092  terra fuochi campania celebra eccellenze inaug...      1            1
# 1701  salvini sbaglia redigere comunicato estende li...      1            1
# 2036  meeting fdi giorgia meloni prende distanze fas...      1            1
# 9992  accordo cessate fuoco gaza entro lunedì cosa c...      0            0
# 730   crollo viadotto torinosavona protezione civile...      1            1

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def evaluate_predictions(df):
    errors = df[df['Label'] != df['predictions']]
    num_errors = len(errors)
    
    print(f"\nNumber of errors: {num_errors}\n")
    
    accuracy = accuracy_score(df['Label'], df['predictions'])
    f1 = f1_score(df['Label'], df['predictions'])
    precision = precision_score(df['Label'], df['predictions'])
    recall = recall_score(df['Label'], df['predictions'])

    print(f"Accuracy: {accuracy}")
    print(f"F1 Score: {f1}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}\n")

    print("Misclassified titles:\n")
    for index, row in errors.iterrows():
        label = "sarcastic" if row['Label'] == 1 else "not sarcastic"
        prediction = "sarcastic" if row['predictions'] == 1 else "not sarcastic"
        print(f"Title: {row['titles']}, Label: {label}, Prediction: {prediction}")

# %%
evaluate_predictions(df_pred)
# Out:
# Number of errors: 163
#
# Accuracy: 0.8576419213973799
# F1 Score: 0.8688656476267096
# Precision: 0.8294930875576036
# Recall: 0.9121621621621622
#
# Misclassified titles:
#
# Title: francesco corvaro nuovo inviato clima farnesina nominato tajani pichetto fratin, Label: not sarcastic, Prediction: sarcastic
# Title: prosegue sciame sismico intorno parma spoleto umbria scuole chiuse scosse, Label: not sarcastic, Prediction: sarcastic
# Title: arriva nuovo brano inedito beatles 2 novembre esce now and then stato realizzato, Label: not sarcastic, Prediction: sarcastic
# Title: convivenza neanderthal prima previsto lenigma irrisolto due teschi, Label: not sarcastic, Prediction: sarcastic
# Title: renato brunetta stipendio cnel norma hoc governo meloni decreto pnrr, Label: not sarcastic, Prediction: sarcastic
# Title: macron verso rimpasto governo dimette premier francese elisabeth borne, Label: not sarcastic, Prediction: sarcastic
# Title: solo giorno iphone x 1 euro attenti cecchini, Label: sarcastic, Prediction: not sarcastic
# Title: dora lagreca lipotesi incompatibile suicidio caduta verticale senza slancio, Label: not sarcastic, Prediction: sarcastic
# Title: nasa capo navicella orion entro 2030 esseri umani potranno vivere lavorare luna, Label: not sarcastic, Prediction: sarcastic
# Title: lol 5 rischio lannuncio prime finiti jackal far partecipare, Label: sarcastic, Prediction: not sarcastic
# Title: creato primo batterio genoma interamente riscritto, Label: not sarcastic, Prediction: sarcastic
# Title: elezioni usa ritardo spoglio voti postali primo dati vantaggio abramo lincoln, Label: sarcastic, Prediction: not sarcastic
# Title: allerta dengue italia cura previene febbre viene trasmessa zanzare, Label: not sarcastic, Prediction: sarcastic
# Title: superbonus approvato notturna lemendamento spalmare crediti 2024, Label: not sarcastic, Prediction: sarcastic
# Title: prime parole ct luciano spalletti spero far rinascere sogno nazionale, Label: not sarcastic, Prediction: sarcastic
# Title: keith richards starnutisce studente manda overdose, Label: sarcastic, Prediction: not sarcastic
# Title: litio metallo premio nobel cambiato mondo vite, Label: not sarcastic, Prediction: sarcastic
# Title: macerata ragazzo spara 6 razzisti anziano spara 6 ragazzi dirigente inps spara 6 anziani, Label: sarcastic, Prediction: not sarcastic
# Title: andrea giambruno rapporto giorgia meloni prendo ordini già sposati, Label: not sarcastic, Prediction: sarcastic
# Title: liguri spot liguria portano turisti, Label: sarcastic, Prediction: not sarcastic
# Title: servizi segreti vanno tilt ricompare marina ovsyannikova scompare nuovo tennista cinese, Label: sarcastic, Prediction: not sarcastic
# Title: nave aquarius salva cucciolo delfino salvini ordina limmediata riapertura porti, Label: sarcastic, Prediction: not sarcastic
# Title: morto franz beckenbauer addio kaiser calcio mondiale, Label: not sarcastic, Prediction: sarcastic
# Title: consigliere fdi lascia suv posto riservato disabili, Label: not sarcastic, Prediction: sarcastic
# Title: consiglia de martino donna dice essere stata miracolata padre pio, Label: not sarcastic, Prediction: sarcastic
# Title: codice crosbyschøyen libro religioso antico cristianesimo messo allasta londra, Label: not sarcastic, Prediction: sarcastic
# Title: oreo mai fatto accordo beneficenza chiara ferragni, Label: not sarcastic, Prediction: sarcastic
# Title: mancata benedizione cane unità cinofila vendica scovando prove vaticano caso orlandi, Label: sarcastic, Prediction: not sarcastic
# Title: fedez ferragni furiosa rosa chemical fatto pure regalo san valentino, Label: sarcastic, Prediction: not sarcastic
# Title: sothebys inedita foto dargen damico senza occhiali battuta allasta 3 centesimo, Label: sarcastic, Prediction: not sarcastic
# Title: quirinale esperti concordi entro 7 giorni omicron potrebbe eleggere presidente repubblica, Label: sarcastic, Prediction: not sarcastic
# Title: rai 1 imbarazzo momento ghigliottina parola serata nana merda, Label: sarcastic, Prediction: not sarcastic
# Title: festival sanremo nuovo regolamento cantanti eliminati strappata lingua, Label: sarcastic, Prediction: not sarcastic
# Title: figlia 4 anni metro pozzolo momento sparo temuto peggio, Label: not sarcastic, Prediction: sarcastic
# Title: scuola bagni senza carta bambino costretto pulirsi foto presidente denunciato vilipendio, Label: sarcastic, Prediction: not sarcastic
# Title: successo irma testa medaglia doro mondiali boxe nuova delhi, Label: not sarcastic, Prediction: sarcastic
# Title: svendita banchi rotelle 1 euro luno esulta sindaco padovano affare costati, Label: not sarcastic, Prediction: sarcastic
# Title: napoli via circolazione targhe alterne giorno vere giorno false, Label: sarcastic, Prediction: not sarcastic
# Title: mediaset toglie conduzione stasera italia minzolini spiegato motivo lho capito, Label: not sarcastic, Prediction: sarcastic
# Title: afghanistan portavoce talebani chiarisce pronti concedere lamnistia civili già fucilati, Label: sarcastic, Prediction: not sarcastic
# Title: susanna tamaro ecco parodie libri daniele luttazzi, Label: sarcastic, Prediction: not sarcastic
# Title: caro affitti linsegnante costretto fare 5 ore giorno auto raggiungere scuola cortina, Label: not sarcastic, Prediction: sarcastic
# Title: esplode macchina fango redazione de giornale disperso sallusti, Label: sarcastic, Prediction: not sarcastic
# Title: f1 qualifiche folli gp canada fuori q3 leclerc perez, Label: not sarcastic, Prediction: sarcastic
# Title: beppe sala rivelazione malattia due recidive mentre lavoravo expo, Label: not sarcastic, Prediction: sarcastic
# Title: morto vincenzo damico giornalista ex calciatore 68 anni, Label: not sarcastic, Prediction: sarcastic
# Title: marte donna potrebbe essere primo essere umano arrivare pianeta, Label: not sarcastic, Prediction: sarcastic
# Title: romano prodi dire no salario minimo vergogna, Label: not sarcastic, Prediction: sarcastic
# Title: terremoto napoli sciame sismico campi flegrei scosse fino 37 magnitudo, Label: not sarcastic, Prediction: sarcastic
# Title: sanremo 2024 nino dangelo rifiuta duetto ghali torno allariston solo napoletano, Label: not sarcastic, Prediction: sarcastic
# Title: giuseppe garibaldi concorrente malore grande fratello, Label: not sarcastic, Prediction: sarcastic
# Title: avellino padre uccide figlia depressa poi suicida litigavano spesso problemi psichici, Label: not sarcastic, Prediction: sarcastic
# Title: gioco dazzardo sgominato giro scommesse clandestine ritardi treni regionali, Label: sarcastic, Prediction: not sarcastic
# Title: superbonus beppe grillo stretta giorgetti colpevoli ripresa, Label: not sarcastic, Prediction: sarcastic
# Title: conduttrice rai serena bortone ospite verissimo, Label: not sarcastic, Prediction: sarcastic
# Title: lupi smentisce accuse favoritismo lascia lincarico ministro figlio, Label: sarcastic, Prediction: not sarcastic
# Title: rai interviene caso michele guardì avviato audit interno, Label: not sarcastic, Prediction: sarcastic
# Title: agenzia cinese rivendica proprietà scatto buco nero, Label: not sarcastic, Prediction: sarcastic
# Title: telefoni sotto parrucca cuffie orecchie così 50 persone preso patente truffa, Label: not sarcastic, Prediction: sarcastic
# Title: ilaria salis ringrazia mattarella dopo telefonata molto impressionato, Label: not sarcastic, Prediction: sarcastic
# Title: scuola solo studente tre viene punito brutti voti 10 casi genitori prendono prof, Label: not sarcastic, Prediction: sarcastic
# Title: complimenti napoli milanista salvini strameritato messaggio berlusconi san raffaele, Label: not sarcastic, Prediction: sarcastic
# Title: usa 2024 liowa mette turbo corsa trump videocommento, Label: not sarcastic, Prediction: sarcastic
# Title: ucraina ministro kuleba dietro lattacco hamas cè putin, Label: not sarcastic, Prediction: sarcastic
# Title: tav liguria toti treni genova veloci radiamo suolo savona, Label: sarcastic, Prediction: not sarcastic
# Title: camila giorgi sparita telefono staccato risponde nessuno, Label: not sarcastic, Prediction: sarcastic
# Title: mattarella allonu corsa armamenti divora risorse bisogna costruire pace, Label: not sarcastic, Prediction: sarcastic
# Title: usa autorizzato primo test respiratorio rilevare coronavirus, Label: not sarcastic, Prediction: sarcastic
# Title: calcio gratis senza abbonamento dazn lancia modalità free, Label: not sarcastic, Prediction: sarcastic
# Title: toninelli sì governo draghi patto presidente consiglio conte, Label: sarcastic, Prediction: not sarcastic
# Title: torino intossicazione monossido chiesa veglia pasquale 40 fedeli ospedale, Label: not sarcastic, Prediction: sarcastic
# Title: napolieintracht tar sospende divieto vendita biglietti tifosi tedeschi, Label: not sarcastic, Prediction: sarcastic
# Title: bullismo commissione europea richiama litalia lasciate pace molise, Label: sarcastic, Prediction: not sarcastic
# Title: miley cyrus torna disney world arrestata stupro dinamite bla, Label: sarcastic, Prediction: not sarcastic
# Title: nomi ambigui enel santal sindaco venezia vieta libro gender pagine gialle, Label: sarcastic, Prediction: not sarcastic
# Title: ischia mistero tubo gomma attorno collo antonella massa, Label: not sarcastic, Prediction: sarcastic
# Title: sangiuliano parte scurati deve poter esprimere liberamente proprio pensiero, Label: not sarcastic, Prediction: sarcastic
# Title: bullismo commissione europea richiama litalia lasciate pace molise, Label: sarcastic, Prediction: not sarcastic
# Title: johnny depp nuove accuse allex moglie ogni mattina leggeva alta voce caffè gramellini, Label: sarcastic, Prediction: not sarcastic
# Title: fabio capello volta litigò ruud gullit poco arrivammo mani, Label: not sarcastic, Prediction: sarcastic
# Title: chiara ferragni alcuna relazione tomaso trussardi, Label: not sarcastic, Prediction: sarcastic
# Title: arriva lesperto assolve valditara post sgrammaticato nemmeno passaggio criticato, Label: not sarcastic, Prediction: sarcastic
# Title: lutto mondo basket morto 24 anni samuel dilas pivot lumezzane, Label: not sarcastic, Prediction: sarcastic
# Title: netflix scoperto menù segreto può perdere ulteriore tempo scegliere cosa vedere, Label: sarcastic, Prediction: not sarcastic
# Title: tempo fa seconda puntata supera debutto 1126 share, Label: not sarcastic, Prediction: sarcastic
# Title: laurea 110 lode medicina studiando testi cannibal corpse, Label: sarcastic, Prediction: not sarcastic
# Title: aquarius dietrofront spagna litalia detto bordo bonghisti, Label: sarcastic, Prediction: not sarcastic
# Title: quel nero labbiamo visto prima rissa forza nuova casa pound 88 feriti, Label: sarcastic, Prediction: not sarcastic
# Title: arriva prima europee riforma costituzionale separazione carriere magistrati, Label: not sarcastic, Prediction: sarcastic
# Title: michele emiliano luscita m5s giunta puglia chiedono torneranno, Label: not sarcastic, Prediction: sarcastic
# Title: zangrillo pronto clonare berlusconi frammenti dna recuperati lingua centinaia giornalisti, Label: sarcastic, Prediction: not sarcastic
# Title: rom ladro entra pizzeria ubriaca titolare trova ancora addormentato mattina dopo, Label: not sarcastic, Prediction: sarcastic
# Title: lombardia risolta lemergenza case riposo riconvertite cimiteri, Label: sarcastic, Prediction: not sarcastic
# Title: folla fluido matematica spiega gestire panico, Label: not sarcastic, Prediction: sarcastic
# Title: tempesta solare arrivata terra laurora boreale visibile italia, Label: not sarcastic, Prediction: sarcastic
# Title: me reazione palazzo chigi modifica relativo interesse, Label: not sarcastic, Prediction: sarcastic
# Title: nunzia de girolamo programma rai ispiro gianfranco funari, Label: not sarcastic, Prediction: sarcastic
# Title: compagno daniela santanchè milione euro trovare salvarla lunico briatore, Label: not sarcastic, Prediction: sarcastic
# Title: ecco donna appesa jolanda crivelli, Label: not sarcastic, Prediction: sarcastic
# Title: sgarbi verso rinvio giudizio quadro comprato allasta senza pagare tasse, Label: not sarcastic, Prediction: sarcastic
# Title: new york time israele conosceva piano attacco hamas 7 ottobre, Label: not sarcastic, Prediction: sarcastic
# Title: esobiologi nasa riprodotto laboratorio lorigine vita, Label: not sarcastic, Prediction: sarcastic
# Title: anzio ladro seriale preso coltellate giovani giustizieri, Label: not sarcastic, Prediction: sarcastic
# Title: basta ansia riapertura scuole lottimismo remuzzi covid infondato, Label: not sarcastic, Prediction: sarcastic
# Title: sanremo 2024 parte respiro mengoni ecco canzoni cambieranno vita po, Label: not sarcastic, Prediction: sarcastic
# Title: tradisci racconto ilary blasi belén rodriguez va onda linfedeltà partner, Label: not sarcastic, Prediction: sarcastic
# Title: stazione spaziale catturato leco buco nero divora stella, Label: not sarcastic, Prediction: sarcastic
# Title: londra fabrizio corona fermato accusato cannibalismo, Label: sarcastic, Prediction: not sarcastic
# Title: 29 giovanissimi alfieri repubblica scelti mattarella storie, Label: not sarcastic, Prediction: sarcastic
# Title: test antigenico fa scoprire tumori venti minuti quasi, Label: not sarcastic, Prediction: sarcastic
# Title: baby gang iniziato sciopero fame carcere lecco, Label: not sarcastic, Prediction: sarcastic
# Title: sci colpaccio federica brignone azzurro primo oro mondiali, Label: not sarcastic, Prediction: sarcastic
# Title: ispiro idolo neymar dedica cr7 accuse stupro, Label: sarcastic, Prediction: not sarcastic
# Title: occhi alto stanotte arriva superluna resterete delusi sempre, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus studio italiano suggerisce promettenti effetti tocilizumab, Label: not sarcastic, Prediction: sarcastic
# Title: the lancet pubblica studio presunta efficacia sputnik v dubbi restano, Label: not sarcastic, Prediction: sarcastic
# Title: dono te rissa convegno aido sette morti dozzine nuovi organi disponibili, Label: sarcastic, Prediction: not sarcastic
# Title: carabiniere smaschera serial killer sgrammaticati intimandogli esca documenti, Label: sarcastic, Prediction: not sarcastic
# Title: jet militari usa attaccano gruppi militari siria risposta droni iraniani, Label: not sarcastic, Prediction: sarcastic
# Title: usa passo storico medicina primo trapianto grazie stampa 3d cellule umane, Label: not sarcastic, Prediction: sarcastic
# Title: zaki tempo fa fazio riprova ospite seconda puntata, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus isolati anticorpi efficaci virus aiuteranno creare nuovi farmaci, Label: not sarcastic, Prediction: sarcastic
# Title: family day critiche scelta rom città fondata mamma lupa, Label: sarcastic, Prediction: not sarcastic
# Title: chiara ferragni chiede annullare multa milione mossa caso balocco depositati ricorsi tar, Label: not sarcastic, Prediction: sarcastic
# Title: rigopiano condanne salgono 8 22 assoluzioni disastro colposo, Label: not sarcastic, Prediction: sarcastic
# Title: segnalata password sicura comunità lgbtq aggiunge due numeri carattere speciale, Label: sarcastic, Prediction: not sarcastic
# Title: medicina ecco ascoltare achille lauro allevia dolori mestruali, Label: sarcastic, Prediction: not sarcastic
# Title: ecco nuova bibbia gender adamo gay eva lesbica caino adottato abele nato provetta, Label: sarcastic, Prediction: not sarcastic
# Title: usa rinviato tempo indeterminato processo trump florida, Label: not sarcastic, Prediction: sarcastic
# Title: vannacci riappare tv figlio gay accetterei futuro politica mai dire mai, Label: not sarcastic, Prediction: sarcastic
# Title: portula biella presentano 30 concorso posto comune bocciati, Label: not sarcastic, Prediction: sarcastic
# Title: ilary blasi global warming innalzamento mari mette rischio lisola famosi, Label: sarcastic, Prediction: not sarcastic
# Title: morto 89 anni just fontaine leggenda calcio francese, Label: not sarcastic, Prediction: sarcastic
# Title: solo segno italiani giorgia meloni riforma zodiaco, Label: sarcastic, Prediction: not sarcastic
# Title: diffamazione maggioranza ritira emendamenti reintroducevano carcere giornalisti, Label: not sarcastic, Prediction: sarcastic
# Title: salone libro ministro sangiuliano basta squadristi, Label: not sarcastic, Prediction: sarcastic
# Title: cantante scialpi marito lasciato oggi vorrei fidanzato giorno, Label: not sarcastic, Prediction: sarcastic
# Title: striscia notizia fa pulci televoto sanremo mancano due milioni voti, Label: not sarcastic, Prediction: sarcastic
# Title: riforma costituzionale arriva cdm bozza premierato cè norma anti ribaltone, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus virus cambiando meno letale studio internazionale fa sperare molti paesi litalia, Label: not sarcastic, Prediction: sarcastic
# Title: principe william rompe silenzio gaza subito cessate fuoco, Label: not sarcastic, Prediction: sarcastic
# Title: governo ridurre disoccupazione città rai girerà altre 174 serie ambientate napoli, Label: sarcastic, Prediction: not sarcastic
# Title: pino insegno vinto oramai certo ritorno conduzione reazione catena, Label: not sarcastic, Prediction: sarcastic
# Title: smarrito filtro giallo ocra sospesa serie tv ambientata messico, Label: sarcastic, Prediction: not sarcastic
# Title: internazionali rom berrettini annuncia ritiro pronto rischio farmi male, Label: not sarcastic, Prediction: sarcastic
# Title: paolo sorrentino tampona qualcuno ingaggia toni servillo falso testimone, Label: sarcastic, Prediction: not sarcastic
# Title: vaccini nuovo errore iniettate sbaglio 22enne tre milioni dosi, Label: sarcastic, Prediction: not sarcastic
# Title: calcio scommesse rom nord trema cerca ra giocate, Label: not sarcastic, Prediction: sarcastic
# Title: re criptovalute sam bankmanfried condannato 25 anni carcere, Label: not sarcastic, Prediction: sarcastic
# Title: ecco cosa succede fate bollire lacqua rubinetto video, Label: sarcastic, Prediction: not sarcastic
# Title: grecia parlamento legalizza matrimoni adozioni coppie omosessuali, Label: not sarcastic, Prediction: sarcastic
# Title: paghetta figli medium 54 euro mese datela solo svolge lavoretti, Label: not sarcastic, Prediction: sarcastic
# Title: scuole insegni rete pizzica valditara scivolato sullitaliano, Label: not sarcastic, Prediction: sarcastic
# Title: immigrazione nuovi cpr dovrà pagare cauzione 4938 euro, Label: not sarcastic, Prediction: sarcastic
# Title: riad renzi complimentato arabo parlando inglese, Label: sarcastic, Prediction: not sarcastic
# Title: lultimo lancio dadi vaccino hiv via sperimentazione, Label: not sarcastic, Prediction: sarcastic
# Title: iraq nuova legge anti lgbt 15 anni carcere relazioni gay 3 anni persone trans, Label: not sarcastic, Prediction: sarcastic
# Title: vanessa incontrada molestatore spagnolo taglierei mani, Label: not sarcastic, Prediction: sarcastic
# Title: donald trump candidato presidente repubblicani vittoria mini super tuesday, Label: not sarcastic, Prediction: sarcastic
# Title: vannacci diventa caso lega giorgetti smarca condivido, Label: not sarcastic, Prediction: sarcastic
# Title: chiara ferragni lieto annuncio aspetto nuovo profilo instagram, Label: sarcastic, Prediction: not sarcastic
# Title: rom ragazza precipita 5 metri terrazza pincio, Label: not sarcastic, Prediction: sarcastic
# Title: afghanistan portavoce talebani chiarisce pronti concedere lamnistia civili già fucilati, Label: sarcastic, Prediction: not sarcastic

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = df_pred['Label']
predicted_labels = df_pred['predictions']

conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = df_pred['Label']
predicted_labels = df_pred['predictions']

conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(true_labels, predicted_labels, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Calibration Curve', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('Predicted Probability')
plt.ylabel('True Probability')
plt.title('Calibration Curve')
plt.legend(loc='lower right')
plt.show()
