# %%
import os
os.chdir('/Users/nico/Desktop/Github')
print(os.getcwd())
# Out:
# /Users/nico/Desktop/Github

# %%
import pandas as pd

df = pd.read_csv('sarcasm_detection/data/corpora_sarcastic_merged.csv')
df.head()
# Out:
#                                               titles  Label
# 0  Trentino, femministe chiedono l'abbattimento d...      1
# 1  "Voglio essere come lui!" Bambino guarda video...      1
# 2  "Vorrei staccare la spina". Sospeso medico ria...      1
# 3  Gatta muore al pronto soccorso per animali, ve...      1
# 4  Bologna, Comune installa sui semafori piccioni...      1

# %%
from sklearn.model_selection import train_test_split

train_texts, temp_texts, train_labels, temp_labels = train_test_split(df['titles'], df['Label'], test_size=0.2, random_state=42)

val_texts, test_texts, val_labels, test_labels = train_test_split(temp_texts, temp_labels, test_size=0.5, random_state=42)

# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import ElectraTokenizer, ElectraForSequenceClassification, AlbertForSequenceClassification

model_name = 'google/electra-small-discriminator'

# tokenizer
tokenizer = ElectraTokenizer.from_pretrained(model_name)

# Tokenize the texts
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True)

val_encodings = tokenizer(val_texts.tolist(), truncation=True, padding=True)

test_encodings = tokenizer(test_texts.tolist(), truncation=True, padding=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import torch

# define a PyTorch dataset

class SarcasmDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
         self.encodings = encodings
         self.labels = labels
        
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]) 
        return item
        
    def __len__(self):
        return len(self.labels)

# %%
# convert our tokenized data into a torch datasets
train_dataset = SarcasmDataset(train_encodings, train_labels.tolist())
val_dataset = SarcasmDataset(val_encodings, val_labels.tolist())
test_dataset = SarcasmDataset(test_encodings, test_labels.tolist())

# %%
model = ElectraForSequenceClassification.from_pretrained(model_name)  # num_labels=2 for binary classification
# Out:
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-small-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer, TrainingArguments

# training arguments
training_args = TrainingArguments(
    output_dir='./outputs',
    num_train_epochs=1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=64,
    warmup_steps=100,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_strategy='steps',
    logging_steps=25,
    evaluation_strategy='steps',
    save_steps=50,
    eval_steps=50,
    load_best_model_at_end=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='413' max='413' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [413/413 05:20, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.649400</td>
#       <td>0.593241</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.426900</td>
#       <td>0.347737</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.327500</td>
#       <td>0.322723</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.262200</td>
#       <td>0.221170</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.195200</td>
#       <td>0.189869</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.212700</td>
#       <td>0.170508</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.172200</td>
#       <td>0.147493</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.146300</td>
#       <td>0.134552</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=413, training_loss=0.30864064052664913, metrics={'train_runtime': 322.3807, 'train_samples_per_second': 40.995, 'train_steps_per_second': 1.281, 'total_flos': 51638824570368.0, 'train_loss': 0.30864064052664913, 'epoch': 1.0})

# %%
import matplotlib.pyplot as plt

train_stats = trainer.state.log_history

train_loss = [x['loss'] for x in train_stats if 'loss' in x]
eval_loss = [x['eval_loss'] for x in train_stats if 'eval_loss' in x]

train_steps = [x['step'] for x in train_stats if 'loss' in x]
eval_steps = [x['step'] for x in train_stats if 'eval_loss' in x]

plt.figure(figsize=(10, 6))
plt.plot(train_steps, train_loss, label='Training Loss')
plt.plot(eval_steps, eval_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Losses Over Steps')
plt.show()

# %%
import numpy as np

# Evaluate the model
eval_results = trainer.evaluate(test_dataset)

# Print evaluation results
print(eval_results)

# Predict on new data
predictions = trainer.predict(test_dataset)

# The predictions are in logits. Convert them to class labels.
predicted_labels = np.argmax(predictions.predictions, axis=1)

print(predicted_labels)
# Out:
#     <div>
#
#       <progress value='2' max='26' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2/26 00:00 < 00:14, 1.65 it/s]
#     </div>

# %% [markdown]
# ### here i build a test set composed by the real labels and the predictions in order to visually compare the pred. results

# %%
df_pred = pd.DataFrame({
    'titles': test_texts,
    'Label': test_labels
})

df_pred['predictions'] = predicted_labels

df_pred.head()
# Out:
#                                                   titles  Label  predictions
# 10359  Alcune multinazionali dell’energia stanno anda...      0            0
# 3886   Chiara Ferragni lancia la sua linea di Green Pass      1            1
# 2129   Inchiesta shock di Repubblica: "Perché anche i...      1            1
# 16443  “Zombie” dei Cranberries alla Coppa del Mondo ...      0            0
# 7313   I partitini di centro non smettono di contende...      0            0

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def evaluate_predictions(df):
    errors = df[df['Label'] != df['predictions']]
    num_errors = len(errors)
    
    print(f"\nNumber of errors: {num_errors}\n")
    
    accuracy = accuracy_score(df['Label'], df['predictions'])
    f1 = f1_score(df['Label'], df['predictions'])
    precision = precision_score(df['Label'], df['predictions'])
    recall = recall_score(df['Label'], df['predictions'])

    print(f"Accuracy: {accuracy}")
    print(f"F1 Score: {f1}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}\n")

    print("Misclassified titles:\n")
    for index, row in errors.iterrows():
        label = "sarcastic" if row['Label'] == 1 else "not sarcastic"
        prediction = "sarcastic" if row['predictions'] == 1 else "not sarcastic"
        print(f"Title: {row['titles']}, Label: {label}, Prediction: {prediction}")

# %%
evaluate_predictions(df_pred)
# Out:
# Number of errors: 93
#
# Accuracy: 0.9437386569872959
# F1 Score: 0.9212531752751905
# Precision: 0.9251700680272109
# Recall: 0.9173693086003373
#
# Misclassified titles:
#
# Title: Dizionario minimo per seguire le telecronache del tennis, Label: not sarcastic, Prediction: sarcastic
# Title: STRAMACCIONI PERDE L’ENNESIMA PARTITA E VIENE NOMINATO SEGRETARIO DEL PD, Label: sarcastic, Prediction: not sarcastic
# Title: Cioè, un vecchio giornale per giovanissime, Label: not sarcastic, Prediction: sarcastic
# Title: Fatichiamo ancora a spiegarci il vetro, Label: not sarcastic, Prediction: sarcastic
# Title: Fortunato Ortombina sarà nominato sovrintendente della Scala di Milano, Label: not sarcastic, Prediction: sarcastic
# Title: Ragazza accompagna l’amica ad un’audizione e non viene presa al posto suo, Label: sarcastic, Prediction: not sarcastic
# Title: Santanchè dice che si arricchirà «con tutte le querele», Label: not sarcastic, Prediction: sarcastic
# Title: Te lo puntella mentre dormi? Da oggi puoi chiedere il divorzio, Label: sarcastic, Prediction: not sarcastic
# Title: Qualche statistica notevole della vittoria di Sinner contro Djokovic, Label: not sarcastic, Prediction: sarcastic
# Title: È DICK CHENEY IL CACCIATORE CHE UCCISE LA MADRE DI BAMBI, Label: sarcastic, Prediction: not sarcastic
# Title: Snapchat non vuole trasferirci tutti nel metaverso, Label: not sarcastic, Prediction: sarcastic
# Title: Gianna Pentenero sarà la candidata del Partito Democratico alle elezioni regionali in Piemonte, Label: not sarcastic, Prediction: sarcastic
# Title: Il ministro Kyenge si dimette, al suo posto Burzum, Label: sarcastic, Prediction: not sarcastic
# Title: Trump scorda i codici nucleari, la CIA ricorre al waterboarding per farglieli tornare in mente, Label: sarcastic, Prediction: not sarcastic
# Title: Avvistato velivolo all’aeroporto di Crotone, Label: sarcastic, Prediction: not sarcastic
# Title: Ilaria Salis sarà candidata al Parlamento Europeo con Alleanza Verdi e Sinistra, Label: not sarcastic, Prediction: sarcastic
# Title: Cosplayer di Arancia Meccanica si fanno prendere la mano e devastano il Lucca Comics, Label: sarcastic, Prediction: not sarcastic
# Title: Snapchat non vuole trasferirci tutti nel metaverso, Label: not sarcastic, Prediction: sarcastic
# Title: Proseguono anche oggi le proteste degli agricoltori, con qualche disagio per la circolazione stradale, Label: not sarcastic, Prediction: sarcastic
# Title: Lamborghini introdurrà la settimana lavorativa da quattro giorni per i propri dipendenti, Label: not sarcastic, Prediction: sarcastic
# Title: Avis apre alle donazioni di sangue mestruale, Label: sarcastic, Prediction: not sarcastic
# Title: Stacca gli occhi dal cellulare e scopre di essere arrivato a piedi in Russia, Label: sarcastic, Prediction: not sarcastic
# Title: IL GATTO DI SCHRÖDINGER È VIVO, Label: sarcastic, Prediction: not sarcastic
# Title: Apparse stimmate a forma di tacchetti di Messi sulle mani di Lele Adani, Label: sarcastic, Prediction: not sarcastic
# Title: Dilettante, scienziata, attivista, simbolo, Label: not sarcastic, Prediction: sarcastic
# Title: Ricostruire voci che non esistono più, Label: not sarcastic, Prediction: sarcastic
# Title: Meloni spera che con Schlein il PD «guardi avanti e non indietro», Label: not sarcastic, Prediction: sarcastic
# Title: Diffusa la prima foto di Samantha Cristoforetti vista dalla Terra, Label: sarcastic, Prediction: not sarcastic
# Title: Gli si blocca la app per la corsa, muore di fatica per bruciare 100 calorie, Label: sarcastic, Prediction: not sarcastic
# Title: Venti dischi del 2023 che vale la pena ascoltare, Label: not sarcastic, Prediction: sarcastic
# Title: Meloni preferisce Schlein come sua avversaria diretta, Label: not sarcastic, Prediction: sarcastic
# Title: Si sciolgono i Teletubbies, Tinky Winky pronto per la carriera solista, Label: sarcastic, Prediction: not sarcastic
# Title: Investire in borse di lusso rende parecchio, Label: not sarcastic, Prediction: sarcastic
# Title: Cieco recupera la vista e inneggia a Satana, Label: sarcastic, Prediction: not sarcastic
# Title: Agenzia di viaggi organizza tour nel Mediterraneo per vedere i profughi affondare sui barconi, Label: sarcastic, Prediction: not sarcastic
# Title: I Negramaro scrivono una canzone che non menziona fenomeni atmosferici, Label: sarcastic, Prediction: not sarcastic
# Title: «Attenzione borseggiatrici, attenzione pickpocket!», Label: not sarcastic, Prediction: sarcastic
# Title: In Spagna si litiga su un ritratto di Gesù: troppo svestito e poco mascolino, Label: not sarcastic, Prediction: sarcastic
# Title: UE ha deciso, forbici diventano ufficialmente una posata, Label: sarcastic, Prediction: not sarcastic
# Title: David Puente debunka oroscopo di Paolo Fox, Label: sarcastic, Prediction: not sarcastic
# Title: Ilaria Salis sarà candidata al Parlamento Europeo con Alleanza Verdi e Sinistra, Label: not sarcastic, Prediction: sarcastic
# Title: M5S propone referendum per dimezzare il numero di contagi, Label: sarcastic, Prediction: not sarcastic
# Title: Spotify farà di più per contenere la disinformazione sul coronavirus, Label: not sarcastic, Prediction: sarcastic
# Title: «Attenzione borseggiatrici, attenzione pickpocket!», Label: not sarcastic, Prediction: sarcastic
# Title: Continua l’anno d’oro dell’Italia: prima anche nella classifica delle morti sul lavoro, Label: sarcastic, Prediction: not sarcastic
# Title: Pio e Amedeo fanno un nuovo monologo e ricevono i complimenti da Erdogan, Label: sarcastic, Prediction: not sarcastic
# Title: Tutto sugli ingressi a pagamento a Venezia, Label: not sarcastic, Prediction: sarcastic
# Title: Couchsurfing.com non è più quello di una volta, Label: not sarcastic, Prediction: sarcastic
# Title: Samantha Cristoforetti sarà la prossima comandante della Stazione Spaziale Internazionale, Label: not sarcastic, Prediction: sarcastic
# Title: Iphone 6 leggerà il pensiero, Label: sarcastic, Prediction: not sarcastic
# Title: Ex fumatore trova 10 accendini frugando tra i vecchi vestiti e si compra le Seychelles, Label: sarcastic, Prediction: not sarcastic
# Title: Rita Dalla Chiesa eletta vicepresidente al CSM, Label: sarcastic, Prediction: not sarcastic
# Title: È allarme per la nuova droga che ti fa credere di aver sentito una dichiarazione di Zingaretti, Label: sarcastic, Prediction: not sarcastic
# Title: IL MALE, BIMBO DI CINQUE ANNI PRENDE IL POSTO DI VINCINO - LE VIGNETTE, Label: sarcastic, Prediction: not sarcastic
# Title: Silvio Berlusconi assolto dal tribunale di Forum, Label: sarcastic, Prediction: not sarcastic
# Title: Scia chimica turca abbatte scia chimica russa, Label: sarcastic, Prediction: not sarcastic
# Title: COMPRA DIVANO E CI TROVA DENTRO SABRINA FERILLI, Label: sarcastic, Prediction: not sarcastic
# Title: Akebono Taro era un gigante anche tra i lottatori di sumo, Label: not sarcastic, Prediction: sarcastic
# Title: In arrivo il film su San Patrignano con Favino nella parte di 1000 drogati, Label: sarcastic, Prediction: not sarcastic
# Title: Oscar Pistorius, il più famoso atleta paralimpico di sempre, è uscito di prigione, Label: not sarcastic, Prediction: sarcastic
# Title: LUCA GIURATO SARÀ JAMES BOND NEL PROSSIMO 007, Label: sarcastic, Prediction: not sarcastic
# Title: Moltissimi utenti in tutto il mondo hanno avuto problemi ad accedere a Spotify, Label: not sarcastic, Prediction: sarcastic
# Title: Vota Lercio ai Macchianera Italian Awards 2014, Label: sarcastic, Prediction: not sarcastic
# Title: Stacca gli occhi dal cellulare e scopre di essere arrivato a piedi in Russia, Label: sarcastic, Prediction: not sarcastic
# Title: Azienda lancia la carta igienica digitale, Label: sarcastic, Prediction: not sarcastic
# Title: Arriva una Greta Thunberg malvagia che non crede al riscaldamento globale, Label: sarcastic, Prediction: not sarcastic
# Title: Addio a Roberto Benigni, stroncato da un male incurabile alla coerenza, Label: sarcastic, Prediction: not sarcastic
# Title: Chiama linea erotica e gli risponde la madre, Label: sarcastic, Prediction: not sarcastic
# Title: Ekrem Imamoglu, il principale rivale politico di Erdogan, Label: not sarcastic, Prediction: sarcastic
# Title: Spot, canzoni, meme, maschere e cartonati: in India Narendra Modi è ovunque, Label: not sarcastic, Prediction: sarcastic
# Title: Scegliere una giuria che giudichi Trump è ancora più difficile del solito, Label: not sarcastic, Prediction: sarcastic
# Title: Piantedosi dice che il governo non ha impedito i soccorsi per il naufragio di Cutro, Label: not sarcastic, Prediction: sarcastic
# Title: Guardare più video contemporaneamente per concentrarsi meglio, Label: not sarcastic, Prediction: sarcastic
# Title: La RAI affida un programma a Nunzia De Girolamo e Pino Insegno e la tv si spegne da sola, Label: sarcastic, Prediction: not sarcastic
# Title: Arrestato per truffa l’inventore dello slogan “Ne usciremo migliori”, Label: sarcastic, Prediction: not sarcastic
# Title: 18 marzo 1978: l’omicidio di Fausto Tinelli e Lorenzo Iannucci, Label: not sarcastic, Prediction: sarcastic
# Title: Fa credere al gatto di vivere a Vicenza per non farlo scappare di casa, Label: sarcastic, Prediction: not sarcastic
# Title: Quella famosa frase di Cantona sui gabbiani e le sardine non voleva dire niente, Label: not sarcastic, Prediction: sarcastic
# Title: È POLEMICA PER IL NUOVO SPOT DEL VIAGRA CON LUCA SARDELLA E JANIRA MAJELLO, Label: sarcastic, Prediction: not sarcastic
# Title: Italia contro All Blacks: 15 sconfitte su 15 partite, ma ci riproviamo, Label: not sarcastic, Prediction: sarcastic
# Title: Conte chiede a Fassino di profetizzare che il governo durerà poco, Label: sarcastic, Prediction: not sarcastic
# Title: Questa idea dei taxi volanti non è così fantascientifica, Label: not sarcastic, Prediction: sarcastic
# Title: La Settimana Enigmistica pubblica un gioco nuovo, vecchio fan ne muore, Label: sarcastic, Prediction: not sarcastic
# Title: Continua l’anno d’oro dell’Italia: prima anche nella classifica delle morti sul lavoro, Label: sarcastic, Prediction: not sarcastic
# Title: Nordio vuole cambiare il concorso esterno in associazione mafiosa, Label: not sarcastic, Prediction: sarcastic
# Title: Beniamino Zuncheddu, incarcerato ingiustamente per 32 anni, è stato assolto, Label: not sarcastic, Prediction: sarcastic
# Title: LO SPELLING DIVENTA INTERNAZIONALE? E DOMODOSSOLA FA RICORSO, Label: sarcastic, Prediction: not sarcastic
# Title: UNIONE EUROPEA APPROVA LA PATENTE DI VOTO, DEMOCRAZIA A RISCHIO, Label: sarcastic, Prediction: not sarcastic
# Title: Sappiamo ancora poco degli effetti dei tatuaggi sulla salute, Label: not sarcastic, Prediction: sarcastic
# Title: Rom ruba 49 milioni di euro e viene nominato tesoriere della Lega, Label: sarcastic, Prediction: not sarcastic
# Title: Nicolò Fagioli, giocatore della Juventus, ha ricevuto una squalifica di sette mesi per aver scommesso illegalmente sul calcio, Label: not sarcastic, Prediction: sarcastic
# Title: Cambiare operatore telefonico è diventato più sicuro, ma anche più complicato, Label: not sarcastic, Prediction: sarcastic
# Title: Pensavo Peccioli 2024, per attraversare le cose, Label: not sarcastic, Prediction: sarcastic

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = df_pred['Label']
predicted_labels = df_pred['predictions']

conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

precision, recall, _ = precision_recall_curve(true_labels, predicted_labels)
average_precision = average_precision_score(true_labels, predicted_labels)

# Plot precision-recall curve
plt.figure(figsize=(8, 6))
plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve (AP={0:0.2f})'.format(average_precision))
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(true_labels, predicted_labels, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Calibration Curve', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('Predicted Probability')
plt.ylabel('True Probability')
plt.title('Calibration Curve')
plt.legend(loc='lower right')
plt.show()
