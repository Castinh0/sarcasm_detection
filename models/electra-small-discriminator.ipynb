# %%
import os
os.chdir('/Users/nico/Desktop/Github')
print(os.getcwd())
# Out:
# /Users/nico/Desktop/Github

# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk
import numpy as np

# %%
df = pd.read_csv('sarcasm_detection/data/corpora_dataset.csv', sep=';')
df.head()
# Out:
#                                               titles category  Label
# 0  Trentino, femministe chiedono l'abbattimento d...  cronaca      1
# 1  "Voglio essere come lui!" Bambino guarda video...  cronaca      1
# 2  "Vorrei staccare la spina". Sospeso medico ria...  cronaca      1
# 3  Gatta muore al pronto soccorso per animali, ve...  cronaca      1
# 4  Bologna, Comune installa sui semafori piccioni...  cronaca      1

# %%
label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
n_positive = df[df['Label'] == 1].shape[0]  # Number of sarcastic examples
n_negative = df[df['Label'] == 0].shape[0]  # Number of non-sarcastic examples

rows_to_remove = n_negative - n_positive

if pd.api.types.is_numeric_dtype(df.index):  # If index is numeric
    rows_to_delete = np.random.choice(df[df['Label'] == 0].index, rows_to_remove, replace=False)
else:  # If index is not numeric (e.g., strings)
    rows_to_delete = list(df[df['Label'] == 0].sample(rows_to_remove, replace=False).index)

df = df.drop(rows_to_delete)


label_counts = df['Label'].value_counts()

label_names = ['Not Sarcastic', 'Sarcastic']

plt.bar(label_names, label_counts)
plt.xlabel('Label')
plt.ylabel('Number of Examples')
plt.title('Distribution of Sarcastic vs. Not Sarcastic Examples')
plt.show()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/nico/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

df = df[df['titles'].str.len() >= 20] # remove short titles

df['titles'] = df['titles'].str.lower() # lowercasing

df['titles'] = df['titles'].str.replace('[^\w\s]', '', regex=True) # removing punctuation

#df['titles'] = df['titles'].str.replace('\d+', '', regex=True) # removing numbers?

# Removing stop words
stop = set(stopwords.words('italian'))
df['titles'] = df['titles'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop]))

# lemmatization
lemmatizer = WordNetLemmatizer()
df['titles'] = df['titles'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# remove extra whitespace
df['titles'] = df['titles'].str.strip()
df['titles'] = df['titles'].str.replace('\s+', ' ', regex=True)

df.head()
# Out:
#                                               titles category  Label
# 0  trentino femministe chiedono labbattimento del...  cronaca      1
# 1  voglio essere bambino guarda video salvini dec...  cronaca      1
# 2  vorrei staccare spina sospeso medico rianimato...  cronaca      1
# 3  gatta muore pronto soccorso animali veterinari...  cronaca      1
# 4  bologna comune installa semafori piccioni adde...  cronaca      1

# %%
from sklearn.model_selection import train_test_split

train_texts, temp_texts, train_labels, temp_labels = train_test_split(df['titles'], df['Label'], test_size=0.2, random_state=42)

val_texts, test_texts, val_labels, test_labels = train_test_split(temp_texts, temp_labels, test_size=0.5, random_state=42)

# %%
from transformers import ElectraTokenizer, ElectraForSequenceClassification, AlbertForSequenceClassification

model_name = 'google/electra-small-discriminator'

# tokenizer
tokenizer = ElectraTokenizer.from_pretrained(model_name)

# Tokenize the texts
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True)

val_encodings = tokenizer(val_texts.tolist(), truncation=True, padding=True)

test_encodings = tokenizer(test_texts.tolist(), truncation=True, padding=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
import torch

# define a PyTorch dataset

class SarcasmDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
         self.encodings = encodings
         self.labels = labels
        
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx]) 
        return item
        
    def __len__(self):
        return len(self.labels)

# %%
# convert our tokenized data into a torch datasets
train_dataset = SarcasmDataset(train_encodings, train_labels.tolist())
val_dataset = SarcasmDataset(val_encodings, val_labels.tolist())
test_dataset = SarcasmDataset(test_encodings, test_labels.tolist())

# %%
model = ElectraForSequenceClassification.from_pretrained(model_name)  # num_labels=2 for binary classification
# Out:
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-small-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import Trainer, TrainingArguments, EarlyStoppingCallback

training_args = TrainingArguments(
    output_dir='./outputs',
    num_train_epochs=4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    warmup_steps=100,
    learning_rate=0.0001,
    logging_dir='./logs',
    logging_strategy='steps',
    logging_steps=100,
    evaluation_strategy='steps',
    save_steps=200,
    eval_steps=100,
    load_best_model_at_end=True,
    save_total_limit=2
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2288' max='2288' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2288/2288 06:31, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.648900</td>
#       <td>0.524448</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.538300</td>
#       <td>0.530144</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.515100</td>
#       <td>0.448769</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.457400</td>
#       <td>0.448160</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.457600</td>
#       <td>0.518444</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.422500</td>
#       <td>0.415066</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.383600</td>
#       <td>0.501773</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.392400</td>
#       <td>0.376270</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.372100</td>
#       <td>0.364756</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.357900</td>
#       <td>0.367694</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.338300</td>
#       <td>0.354390</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.300900</td>
#       <td>0.353219</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.261900</td>
#       <td>0.355982</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.274800</td>
#       <td>0.403240</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.266700</td>
#       <td>0.368179</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.270000</td>
#       <td>0.452389</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.278600</td>
#       <td>0.354036</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.189600</td>
#       <td>0.434275</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.232400</td>
#       <td>0.418263</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.245100</td>
#       <td>0.408320</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.248600</td>
#       <td>0.384884</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.215200</td>
#       <td>0.376980</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2288, training_loss=0.34291073742446365, metrics={'train_runtime': 391.7821, 'train_samples_per_second': 93.44, 'train_steps_per_second': 5.84, 'total_flos': 105175215974400.0, 'train_loss': 0.34291073742446365, 'epoch': 4.0})

# %%
train_stats = trainer.state.log_history

train_loss = [x['loss'] for x in train_stats if 'loss' in x]
eval_loss = [x['eval_loss'] for x in train_stats if 'eval_loss' in x]

train_steps = [x['step'] for x in train_stats if 'loss' in x]
eval_steps = [x['step'] for x in train_stats if 'eval_loss' in x]

plt.figure(figsize=(10, 6))
plt.plot(train_steps, train_loss, label='Training Loss')
plt.plot(eval_steps, eval_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Losses Over Steps')
plt.show()

# %%
# Evaluate the model
eval_results = trainer.evaluate(test_dataset)

# Print evaluation results
print(eval_results)

# Predict on new data
predictions = trainer.predict(test_dataset)

# The predictions are in logits. Convert them to class labels.
predicted_labels = np.argmax(predictions.predictions, axis=1)

print(predicted_labels)
# Out:
# {'eval_loss': 0.38224053382873535, 'eval_runtime': 2.113, 'eval_samples_per_second': 541.872, 'eval_steps_per_second': 17.037, 'epoch': 4.0}
# [1 1 1 ... 0 1 1]

# %%
df_pred = pd.DataFrame({
    'titles': test_texts,
    'Label': test_labels
})

df_pred['predictions'] = predicted_labels

df_pred.head()
# Out:
#                                                   titles  Label  predictions
# 4092   terra fuochi campania celebra eccellenze inaug...      1            1
# 1701   salvini sbaglia redigere comunicato estende li...      1            1
# 2036   meeting fdi giorgia meloni prende distanze fas...      1            1
# 10052  gaza usa mettono veto risoluzione onu cessate ...      0            0
# 730    crollo viadotto torinosavona protezione civile...      1            1

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def evaluate_predictions(df):
    errors = df[df['Label'] != df['predictions']]
    num_errors = len(errors)
    
    print(f"\nNumber of errors: {num_errors}\n")
    
    accuracy = accuracy_score(df['Label'], df['predictions'])
    f1 = f1_score(df['Label'], df['predictions'])
    precision = precision_score(df['Label'], df['predictions'])
    recall = recall_score(df['Label'], df['predictions'])

    print(f"Accuracy: {accuracy}")
    print(f"F1 Score: {f1}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}\n")

    print("Misclassified titles:\n")
    for index, row in errors.iterrows():
        label = "sarcastic" if row['Label'] == 1 else "not sarcastic"
        prediction = "sarcastic" if row['predictions'] == 1 else "not sarcastic"
        print(f"Title: {row['titles']}, Label: {label}, Prediction: {prediction}")

# %%
evaluate_predictions(df_pred)
# Out:
# Number of errors: 178
#
# Accuracy: 0.8445414847161572
# F1 Score: 0.8555194805194806
# Precision: 0.8234375
# Recall: 0.8902027027027027
#
# Misclassified titles:
#
# Title: saviano condannato diffamazione multa 1000 euro linsulto meloni, Label: not sarcastic, Prediction: sarcastic
# Title: scuole insegni rete pizzica valditara scivolato sullitaliano, Label: not sarcastic, Prediction: sarcastic
# Title: ritratto famigliare trump sotto lalbero natale maralago dovè melania, Label: not sarcastic, Prediction: sarcastic
# Title: morte costanzo settimanale rivela massimo lopez leggerà testamento imitando voce, Label: sarcastic, Prediction: not sarcastic
# Title: pechino 2022 trovato palaghiaccio atleta giapponese convinto olimpiadi finite, Label: sarcastic, Prediction: not sarcastic
# Title: lotta camorra matteo salvini fa selfie mentre mangia due babà, Label: sarcastic, Prediction: not sarcastic
# Title: rover exomars prepara lancio lobiettivo cercare vita marte, Label: not sarcastic, Prediction: sarcastic
# Title: studio digiuno intermittente aumenta rischio morte eventi cardiovascolari, Label: not sarcastic, Prediction: sarcastic
# Title: king marracash primo rapper protagonista tour stadi, Label: not sarcastic, Prediction: sarcastic
# Title: lediting genetico neutralizzare lhiv sempre punto terapia sperimentata topi, Label: not sarcastic, Prediction: sarcastic
# Title: covid varianti preoccupanti interessanti qual differenza vaccini funzionano stesso, Label: not sarcastic, Prediction: sarcastic
# Title: psicologo lancini gruppi whatsapp genitori vanno chiusi vietiamo cellulari scuola, Label: not sarcastic, Prediction: sarcastic
# Title: macerata ragazzo spara 6 razzisti anziano spara 6 ragazzi dirigente inps spara 6 anziani, Label: sarcastic, Prediction: not sarcastic
# Title: preside picchiato scuola materna genitori educano prendono solo difese figli, Label: not sarcastic, Prediction: sarcastic
# Title: zeman meglio piccola ischemia cerebrale medici dovrà smettere fumare, Label: not sarcastic, Prediction: sarcastic
# Title: giuseppe conte elly schlein cambi pd prima pd cambiare, Label: not sarcastic, Prediction: sarcastic
# Title: incoronata boccia far ascoltare donna abortire battito cuore crudele, Label: not sarcastic, Prediction: sarcastic
# Title: lettera salvini elezioni lunione europea re nudo, Label: not sarcastic, Prediction: sarcastic
# Title: sciopero nazionale supermercati vigilia pasqua, Label: not sarcastic, Prediction: sarcastic
# Title: papa francesco chiamato gino cecchettin padre giulia dono, Label: not sarcastic, Prediction: sarcastic
# Title: laccusa procura lotito salvato salernitana soldi lazio, Label: not sarcastic, Prediction: sarcastic
# Title: ignazio russa piace norma antiribaltone premierato meglio tornare voto, Label: not sarcastic, Prediction: sarcastic
# Title: verdetto delloms laspartame possibilmente cancerogeno può continuare consumarlo, Label: not sarcastic, Prediction: sarcastic
# Title: revisione scientifica mostra vaccinati liberano sarscov2 prima vaccinati, Label: not sarcastic, Prediction: sarcastic
# Title: ricercatore studia ufo chiedetemi esistono, Label: not sarcastic, Prediction: sarcastic
# Title: clamorosa sconfitta napoli marisa laurito va bene va bene spoglio, Label: sarcastic, Prediction: not sarcastic
# Title: mancata benedizione cane unità cinofila vendica scovando prove vaticano caso orlandi, Label: sarcastic, Prediction: not sarcastic
# Title: fedez ferragni furiosa rosa chemical fatto pure regalo san valentino, Label: sarcastic, Prediction: not sarcastic
# Title: sothebys inedita foto dargen damico senza occhiali battuta allasta 3 centesimo, Label: sarcastic, Prediction: not sarcastic
# Title: segreto liberato cinema 9 maggio fan chiedono film svelerà finalmente identità, Label: not sarcastic, Prediction: sarcastic
# Title: ritorno casa stefano tacconi dopo malattia adesso cucino, Label: not sarcastic, Prediction: sarcastic
# Title: festival sanremo kamikaze fa esplodere allariston vince premio critica, Label: sarcastic, Prediction: not sarcastic
# Title: scoperto nuovo buco nero dormiente vicino terra mai osservato fino oggi, Label: not sarcastic, Prediction: sarcastic
# Title: quirinale esperti concordi entro 7 giorni omicron potrebbe eleggere presidente repubblica, Label: sarcastic, Prediction: not sarcastic
# Title: novità ryanair potranno portare bordo vescica massimo 100 ml urina, Label: sarcastic, Prediction: not sarcastic
# Title: meloni orban bruxelles caso salis aiuti allucraina, Label: not sarcastic, Prediction: sarcastic
# Title: rai 1 imbarazzo momento ghigliottina parola serata nana merda, Label: sarcastic, Prediction: not sarcastic
# Title: festival sanremo nuovo regolamento cantanti eliminati strappata lingua, Label: sarcastic, Prediction: not sarcastic
# Title: scuola bagni senza carta bambino costretto pulirsi foto presidente denunciato vilipendio, Label: sarcastic, Prediction: not sarcastic
# Title: morto lattore burt young celebre ruolo paulie saga rocky, Label: not sarcastic, Prediction: sarcastic
# Title: iscriviamo azione carlo calenda allarme nuova sfida social estrema, Label: sarcastic, Prediction: not sarcastic
# Title: new hampshire uomo apre fuoco ospedale psichiatrico numerose vittime, Label: not sarcastic, Prediction: sarcastic
# Title: calcio gratis senza abbonamento dazn lancia modalità free, Label: not sarcastic, Prediction: sarcastic
# Title: provocazione mourinho dopo conferma squalifica fa gesto manette 13 anni fa, Label: not sarcastic, Prediction: sarcastic
# Title: potere live social musica piace giovani veri motivi successo geolier, Label: not sarcastic, Prediction: sarcastic
# Title: messico donna accusata aver ucciso bambina linciata folla, Label: not sarcastic, Prediction: sarcastic
# Title: maratona musica tecno producer sviene mixer primo minuto nessuno accorge, Label: sarcastic, Prediction: not sarcastic
# Title: susanna tamaro ecco parodie libri daniele luttazzi, Label: sarcastic, Prediction: not sarcastic
# Title: ponte stretto troppo basso navi crociera container, Label: not sarcastic, Prediction: sarcastic
# Title: giorgia meloni prende distanze destra estrema mussolini fatto cose buonine, Label: sarcastic, Prediction: not sarcastic
# Title: siena chiocciola offende tartuca chiusa contrada razzismo territoriale, Label: sarcastic, Prediction: not sarcastic
# Title: auto inquinanti cdm blocca divieto diesel euro5 scattato piemonte settimana, Label: not sarcastic, Prediction: sarcastic
# Title: drone rivela oltre 100 balene prigioni sottomarine segrete, Label: not sarcastic, Prediction: sarcastic
# Title: alessandro barbano nuovo direttore messaggero laddio riformista renzi dopo mese, Label: not sarcastic, Prediction: sarcastic
# Title: eutanasia legale potrà urlare pizza napoletana fa schifo piazza plebiscito napoli, Label: sarcastic, Prediction: not sarcastic
# Title: migranti meloni annuncia nuova stretta diritto dasilo rimpatriati, Label: not sarcastic, Prediction: sarcastic
# Title: terremoto scossa campi flegrei magnitudo 39 avvertita napoli, Label: not sarcastic, Prediction: sarcastic
# Title: coronavirus nuovo decreto lautocertificazione dovrà essere firmata sangue, Label: sarcastic, Prediction: not sarcastic
# Title: tennis musetti arrende tsitsipas finale barcellona va greco, Label: not sarcastic, Prediction: sarcastic
# Title: cameraman cacciato mediaset molestie sì giambruno no, Label: not sarcastic, Prediction: sarcastic
# Title: soldatessa usa confessa farmi guardare spalle commilitoni fatta crescere tette schiena, Label: sarcastic, Prediction: not sarcastic
# Title: strage erba rosa bazzi esce carcere giorni lavorare cooperativa pulizie, Label: not sarcastic, Prediction: sarcastic
# Title: chiara ferragni annuncia pausa social instagram solo 23 ore mezza giorno, Label: sarcastic, Prediction: not sarcastic
# Title: gioco dazzardo sgominato giro scommesse clandestine ritardi treni regionali, Label: sarcastic, Prediction: not sarcastic
# Title: filo lab imparare classe larte taglio cucito progetto scuole fondazione yolk, Label: not sarcastic, Prediction: sarcastic
# Title: decreto schillaci marijuana codeina droghe stato potranno essere prodotte italia, Label: not sarcastic, Prediction: sarcastic
# Title: efficaci coprifuoco chiusure contrastare diffusione covid19 studio, Label: not sarcastic, Prediction: sarcastic
# Title: marina berlusconi generosità papà silvio qualcuno approfittato amen, Label: not sarcastic, Prediction: sarcastic
# Title: lupi smentisce accuse favoritismo lascia lincarico ministro figlio, Label: sarcastic, Prediction: not sarcastic
# Title: rom dentista scambia tumore gengivite, Label: not sarcastic, Prediction: sarcastic
# Title: marina berlusconi avviato liter nominarla cavaliera lavoro, Label: not sarcastic, Prediction: sarcastic
# Title: lorella cuccarini figlia sessualità fluida ragazzi oggi vuole etichette, Label: not sarcastic, Prediction: sarcastic
# Title: orihimed cameriere robot guidato persone disabili, Label: not sarcastic, Prediction: sarcastic
# Title: benissimo paziente zangrillo corre fare testamento, Label: sarcastic, Prediction: not sarcastic
# Title: giorgia meloni summit natalità ungheria ciò definisce sotto attacco, Label: not sarcastic, Prediction: sarcastic
# Title: dani alves condannato 4 anni mezzo carcere stupro, Label: not sarcastic, Prediction: sarcastic
# Title: firenze blitz ultima generazione attivista scolpisce erezione david eike schmidt incapretta, Label: sarcastic, Prediction: not sarcastic
# Title: netanyahu operato dernia compensare israele troverà dieci palestinesi farla venire, Label: sarcastic, Prediction: not sarcastic
# Title: londra parte mind the gap cinquanta persone incastrate sotto vagoni metro, Label: sarcastic, Prediction: not sarcastic
# Title: decreto pnrr diventa legge via libera senato provita consultori, Label: not sarcastic, Prediction: sarcastic
# Title: mea culpa nunzia de girolamo sbagliato fare avanti popolo, Label: not sarcastic, Prediction: sarcastic
# Title: giorgia meloni prende distanze destra estrema mussolini fatto cose buonine, Label: sarcastic, Prediction: not sarcastic
# Title: marito theresa may netflix 5 anni ancora votando decidere cosa vedere, Label: sarcastic, Prediction: not sarcastic
# Title: studio vaccini mrna miocardite ispirato no vax sbagliato, Label: not sarcastic, Prediction: sarcastic
# Title: fantacalcio mirino dellagenzia entrate giro evasione 2 miliardi euro, Label: sarcastic, Prediction: not sarcastic
# Title: emanuele pozzolo lirriducibile sparato voglio dire stato perizia sbagliano, Label: not sarcastic, Prediction: sarcastic
# Title: carriere alias lombardia consiglio regionale boccia mozione fratelli ditalia, Label: not sarcastic, Prediction: sarcastic
# Title: miley cyrus torna disney world arrestata stupro dinamite bla, Label: sarcastic, Prediction: not sarcastic
# Title: esiste davvero dipendenza smartphone social network, Label: not sarcastic, Prediction: sarcastic
# Title: matteo renzi piano berlusconi quirinale grazia dellutri, Label: not sarcastic, Prediction: sarcastic
# Title: bianca santi commessa sex worker società accetta patriarcale, Label: not sarcastic, Prediction: sarcastic
# Title: moto scooter 125 cc autostrada tangenziale lok allemendamento codice strada, Label: not sarcastic, Prediction: sarcastic
# Title: nuova vita salman rushdie dopo lattentato salvato miracolo credo, Label: not sarcastic, Prediction: sarcastic
# Title: emissioni co2 entro 2035 matteo renzi ridurrà 30 impegno politico, Label: sarcastic, Prediction: not sarcastic
# Title: johnny depp nuove accuse allex moglie ogni mattina leggeva alta voce caffè gramellini, Label: sarcastic, Prediction: not sarcastic
# Title: generale vannacci vedete patriarcato italia libro dedicato madre, Label: not sarcastic, Prediction: sarcastic
# Title: netflix scoperto menù segreto può perdere ulteriore tempo scegliere cosa vedere, Label: sarcastic, Prediction: not sarcastic
# Title: juve ombre john elkann sapeva manovre correttive conti, Label: not sarcastic, Prediction: sarcastic
# Title: scuse massimo ceccherini dopo frase ebrei oscar colpa imbianchino, Label: not sarcastic, Prediction: sarcastic
# Title: esa rivela prima passeggiata spaziale femminile disturbata tamarro molestava, Label: sarcastic, Prediction: not sarcastic
# Title: verona presunta truffa vino fondi ue lagricoltura, Label: not sarcastic, Prediction: sarcastic
# Title: fedez ancora ospedale ferragni rompe silenzio grata, Label: not sarcastic, Prediction: sarcastic
# Title: laurea 110 lode medicina studiando testi cannibal corpse, Label: sarcastic, Prediction: not sarcastic
# Title: fabrizio corona parte combattere ucraina arrende allautista flixbus kiev, Label: sarcastic, Prediction: not sarcastic
# Title: quel nero labbiamo visto prima rissa forza nuova casa pound 88 feriti, Label: sarcastic, Prediction: not sarcastic
# Title: virologo pregliasco no vax insultano strada posso prendere metro, Label: not sarcastic, Prediction: sarcastic
# Title: zangrillo pronto clonare berlusconi frammenti dna recuperati lingua centinaia giornalisti, Label: sarcastic, Prediction: not sarcastic
# Title: ilaria salis racconto zerocalcare budapest esposta trofeo caccia, Label: not sarcastic, Prediction: sarcastic
# Title: convegni normale pisa sulliliade achille prospettiva queer trans, Label: not sarcastic, Prediction: sarcastic
# Title: vannacci diventa caso lega giorgetti smarca condivido, Label: not sarcastic, Prediction: sarcastic
# Title: milano diventa capitale filantropia internazionale 7 l8 marzo, Label: not sarcastic, Prediction: sarcastic
# Title: lazio tecnico maurizio sarri presenta dimissioni, Label: not sarcastic, Prediction: sarcastic
# Title: annullato concerto kanye west campovolo arriva stop prefetto, Label: not sarcastic, Prediction: sarcastic
# Title: svolta toninelli os vuole essere pagato ruolo m5s proposta irrita grillini, Label: not sarcastic, Prediction: sarcastic
# Title: mistero 38 scheletri lago roopkund cosa ucciso tutte persone, Label: not sarcastic, Prediction: sarcastic
# Title: lottatore racconta tentativo corruzione offerto 300 mila dollari perdere, Label: not sarcastic, Prediction: sarcastic
# Title: rom murale jorit allex snia compare scritta gloria allucraina, Label: not sarcastic, Prediction: sarcastic
# Title: ragazzi giustizieri pedofili condannati adescavano chat riempivano botte, Label: not sarcastic, Prediction: sarcastic
# Title: sorride solo rom italiane europa juve salvata gatti ritorno salita fiorentina, Label: not sarcastic, Prediction: sarcastic
# Title: terremoto toscana scossa magnitudo 34 poggibonsi, Label: not sarcastic, Prediction: sarcastic
# Title: elly schlein invitata atreju donzelli smentisce indiscrezioni risulta, Label: not sarcastic, Prediction: sarcastic
# Title: bellezza vistosa enrica bonaccorti pose playboy vergognavo cacciai urlo, Label: not sarcastic, Prediction: sarcastic
# Title: rivoli due ragazzi 15 16 anni sequestrano torturano 50enne soldi, Label: not sarcastic, Prediction: sarcastic
# Title: 50 anni apollo 8 primo viaggio umano attorno luna, Label: not sarcastic, Prediction: sarcastic
# Title: trentino femministe chiedono labbattimento delluomo catturato mentre aggirava boschi, Label: sarcastic, Prediction: not sarcastic
# Title: jihadista tenta farsi esplodere lucca comic fermato 40 capitan america, Label: sarcastic, Prediction: not sarcastic
# Title: nellitalvolley scoppia caso egonu convocata preolimpico chiesto riposo, Label: not sarcastic, Prediction: sarcastic
# Title: manovra maio pressing tria pretendo trovi pentola doro fine dellarcobaleno, Label: sarcastic, Prediction: not sarcastic
# Title: barman feticista accusato drogare violentare ragazze casa, Label: not sarcastic, Prediction: sarcastic
# Title: barbara durso ospita studio federica panicucci insieme danno origine supernova, Label: sarcastic, Prediction: not sarcastic
# Title: londra fabrizio corona fermato accusato cannibalismo, Label: sarcastic, Prediction: not sarcastic
# Title: 29 giovanissimi alfieri repubblica scelti mattarella storie, Label: not sarcastic, Prediction: sarcastic
# Title: vaccini studio confermare mostra lefficacia pfizer 7 mesi booster omicron, Label: not sarcastic, Prediction: sarcastic
# Title: aiuto incendio chiama 112 trovano mini serra canapa casa, Label: not sarcastic, Prediction: sarcastic
# Title: protezione planetarium nasa vaglia nuove regole tutelare mondi esplorare, Label: not sarcastic, Prediction: sarcastic
# Title: dono te rissa convegno aido sette morti dozzine nuovi organi disponibili, Label: sarcastic, Prediction: not sarcastic
# Title: carabiniere smaschera serial killer sgrammaticati intimandogli esca documenti, Label: sarcastic, Prediction: not sarcastic
# Title: tennis impresa matteo arnaldi u open batte norrie vola ottavi, Label: not sarcastic, Prediction: sarcastic
# Title: farmaco chiude porta virus protezione davanti ogni cellula, Label: not sarcastic, Prediction: sarcastic
# Title: renato pozzetto ricorda moglie brunella gubler penso sempre dovuto darle, Label: not sarcastic, Prediction: sarcastic
# Title: eurovision già arrivati svezia primo 200 tir lustrini paillettes, Label: sarcastic, Prediction: not sarcastic
# Title: linkin park annunciano brano inedito voce chester bennington, Label: not sarcastic, Prediction: sarcastic
# Title: giudice apostolico spunta video bambina presta gomma compagno classe africano, Label: sarcastic, Prediction: not sarcastic
# Title: fassino stato denunciato fiumicino controllavano già cascato, Label: not sarcastic, Prediction: sarcastic
# Title: giornalista rivela anni scrivo frasi caso tanto sti stronzi leggono solo titoli, Label: sarcastic, Prediction: not sarcastic
# Title: reinhold messner labbattimento m90 verità orsi trentino troppi, Label: not sarcastic, Prediction: sarcastic
# Title: medicina ecco ascoltare achille lauro allevia dolori mestruali, Label: sarcastic, Prediction: not sarcastic
# Title: ecco nuova bibbia gender adamo gay eva lesbica caino adottato abele nato provetta, Label: sarcastic, Prediction: not sarcastic
# Title: figlio cicciolina processo puntato taser madre, Label: not sarcastic, Prediction: sarcastic
# Title: deserto sahara tornerà abitabile 20mila anni forse sì, Label: not sarcastic, Prediction: sarcastic
# Title: svezia donarono sperma ricerca scoprono essere diventati padri sfruttato, Label: not sarcastic, Prediction: sarcastic
# Title: sente solo chiama carabinieri brindisi arrestato matteo messina denaro, Label: sarcastic, Prediction: not sarcastic
# Title: arriva pizza serpente potrà mangiare ovunque, Label: not sarcastic, Prediction: sarcastic
# Title: errore contabile creativo dovrà restituire allazienda parte visibilità stato pagato, Label: sarcastic, Prediction: not sarcastic
# Title: firenze spray urticante scuola 21 allospedale troveremo responsabili, Label: not sarcastic, Prediction: sarcastic
# Title: male prima peggio seconda mercante fiera pino insegno crolla 2 share, Label: not sarcastic, Prediction: sarcastic
# Title: fabiola gianotti scienziata italiana confermata guida cern, Label: not sarcastic, Prediction: sarcastic
# Title: cambio passo fedez affida comunicazione comin partner, Label: not sarcastic, Prediction: sarcastic
# Title: va pronto soccorso dolori addominali scoprono tubo gel retto opera scappa, Label: not sarcastic, Prediction: sarcastic
# Title: governo ridurre disoccupazione città rai girerà altre 174 serie ambientate napoli, Label: sarcastic, Prediction: not sarcastic
# Title: dc comic sospende batman cattivi arresi dopo legge spazza corrotti, Label: sarcastic, Prediction: not sarcastic
# Title: truffa figlio bruno giordano falso permesso guida dopo ritiro patente, Label: not sarcastic, Prediction: sarcastic
# Title: indagini morte matthew perry friend lipotesi annegamento, Label: not sarcastic, Prediction: sarcastic
# Title: esa rivela prima passeggiata spaziale femminile disturbata tamarro molestava, Label: sarcastic, Prediction: not sarcastic
# Title: sanremo polemiche vignetta charlie hebdo ironizza vittime festival, Label: sarcastic, Prediction: not sarcastic
# Title: chiara ferragni annuncia pausa social instagram solo 23 ore mezza giorno, Label: sarcastic, Prediction: not sarcastic
# Title: paolo sorrentino tampona qualcuno ingaggia toni servillo falso testimone, Label: sarcastic, Prediction: not sarcastic
# Title: me nuovo richiamo dellue allitalia va ratificato prima chiederemo conto giorgetti, Label: not sarcastic, Prediction: sarcastic
# Title: geometra ridotto fin vita calci pugni due ragazze sagra paese molestato, Label: not sarcastic, Prediction: sarcastic
# Title: antropologi sicuri dessimo smartphone neanderthal ascolterebbero musica neomelodica, Label: sarcastic, Prediction: not sarcastic
# Title: ecco cosa succede fate bollire lacqua rubinetto video, Label: sarcastic, Prediction: not sarcastic
# Title: denuncia nyt così israele radendo suolo gaza, Label: not sarcastic, Prediction: sarcastic
# Title: papa francesco benedizione coppie gay temo scisma, Label: not sarcastic, Prediction: sarcastic
# Title: neuralink ok testi clinici esseri umani chip elon musk, Label: not sarcastic, Prediction: sarcastic
# Title: video luci rosse rubato dipendente a rom chiede farsi assumere società, Label: not sarcastic, Prediction: sarcastic
# Title: meloni raddoppia stanziamento aiuti militari allucraina così comici russi imparano, Label: sarcastic, Prediction: not sarcastic
# Title: quando dobbiamo lasciarci fedez lancia sondaggio instagram decidere data divorzio, Label: sarcastic, Prediction: not sarcastic
# Title: nuovo studio sostenitori dellivermectina cure domiciliari stato ritrattato, Label: not sarcastic, Prediction: sarcastic

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

true_labels = df_pred['Label']
predicted_labels = df_pred['predictions']

conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

precision, recall, _ = precision_recall_curve(true_labels, predicted_labels)
average_precision = average_precision_score(true_labels, predicted_labels)

# Plot precision-recall curve
plt.figure(figsize=(8, 6))
plt.step(recall, precision, color='b', alpha=0.7, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.3, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Curve (AP={0:0.2f})'.format(average_precision))
plt.show()

# %%
from sklearn.calibration import calibration_curve

prob_true, prob_pred = calibration_curve(true_labels, predicted_labels, n_bins=10)

plt.figure(figsize=(8, 6))
plt.plot(prob_pred, prob_true, marker='o', label='Calibration Curve', color='blue')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('Predicted Probability')
plt.ylabel('True Probability')
plt.title('Calibration Curve')
plt.legend(loc='lower right')
plt.show()
